# %%
import numpy as np
import pandas as pd

# %%
# path of data

data_path = "/content/smartphones.csv"

df = pd.read_csv(data_path)

df.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %% [markdown]
# 2 types of Data Cleaning ideologies:
#
# 1. Noisy Data/ Dirty Data- Useless data, missing values.
# 2. Messy data - Useful Data but unstructured. --> Structure

# %% [markdown]
# ### Major types of data cleanliness issues:
#
#
# 1. **Completeness Issues** – Data is missing or incomplete where it is expected to be present.
#
# 2. **Validity Issues** – Data doesn't conform to defined formats, types, or rules (e.g., age = -5).
#
# 3. **Consistency Issues** – Conflicting data exists across different systems or columns (e.g., birthdate vs. age mismatch).
#
# 4. **Accuracy Issues** – Data does not reflect the real-world values correctly (e.g., wrong addresses or names).
#
# 5. **Uniqueness Issues** – Duplicate or repeated entries exist where only one should be present.
#
# ---

# %%
# shape of the data

df.shape
# Out:
# (1020, 11)

# %%
# check for missing values

df.isna().sum()
# Out:
# model          0
# price          0
# rating       141
# sim            0
# processor      0
# ram            0
# battery        0
# display        0
# camera         1
# card           7
# os            17
# dtype: int64

# %%
(
    df
    .isna()
    .any(axis=1)
)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1015    False
# 1016    False
# 1017    False
# 1018    False
# 1019    False
# Length: 1020, dtype: bool

# %%
# check for rows having missing values

df.loc[(
    df
    .isna()
    .any(axis=1)
),:]
# Out:
#                             model      price  rating  \
# 14    Samsung Galaxy S23 Ultra 5G  ₹1,14,990     NaN
# 29                 OnePlus 11 Pro    ₹69,999     NaN
# 37    Samsung Galaxy S22 Ultra 5G    ₹91,999     NaN
# 49          Samsung Galaxy A74 5G    ₹42,999     NaN
# 69               Oppo Find N Fold    ₹99,990     NaN
# ...                           ...        ...     ...
# 996                     Vivo Y55S    ₹13,490     NaN
# 1000              XTouch F40 Flip     ₹1,999     NaN
# 1003                      Lava X3     ₹6,999     NaN
# 1012                    itel A23s     ₹4,787     NaN
# 1014                Vivo X Fold 2  ₹1,19,990     NaN
#
#                                                 sim  \
# 14    Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 29          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 37          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 49          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 69          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...                                             ...
# 996                  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1000                                       Dual Sim
# 1003                 Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1012                        Dual Sim, 3G, 4G, Wi-Fi
# 1014        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                               processor  \
# 14      Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 29     Snapdragon  8 Gen2, Octa Core, 3.2 GHz Processor
# 37       Snapdragon  8 Gen1, Octa Core, 3 GHz Processor
# 49     Snapdragon 7 Gen1, Octa Core, 2.36 GHz Processor
# 69    Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# ...                                                 ...
# 996        Snapdragon 425, Quad Core, 1.2 GHz Processor
# 1000                                              No 3G
# 1003              Helio A22, Quad Core, 2 GHz Processor
# 1012  Spreadtrum  SC9832E, Quad Core, 1.4 GHz Processor
# 1014    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                             ram                                   battery  \
# 14     8 GB RAM, 256 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 29     8 GB RAM, 128 GB inbuilt  4500 mAh Battery with 100W Fast Charging
# 37    12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 49     8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 69     8 GB RAM, 256 GB inbuilt   5000 mAh Battery with 67W Fast Charging
# ...                         ...                                       ...
# 996     3 GB RAM, 16 GB inbuilt                          2730 mAh Battery
# 1000                    No Wifi                  32 MB RAM, 32 MB inbuilt
# 1003    3 GB RAM, 32 GB inbuilt                          4000 mAh Battery
# 1012    2 GB RAM, 32 GB inbuilt                          3020 mAh Battery
# 1014  12 GB RAM, 256 GB inbuilt   4800 mAh Battery with 66W Fast Charging
#
#                                                 display  \
# 14    6.8 inches, 1440 x 3088 px, 120 Hz Display wit...
# 29    6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 37    6.8 inches, 1440 x 3080 px, 120 Hz Display wit...
# 49    6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 69    7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# ...                                                 ...
# 996                   5.2 inches, 720 x 1280 px Display
# 1000                                    800 mAh Battery
# 1003  6.5 inches, 1600 x 720 px Display with Water D...
# 1012                     5 inches, 854 x 480 px Display
# 1014        8.03 inches, 1916 x 2160 px, 120 Hz Display
#
#                                                  camera  \
# 14                200 MP Quad Rear & 12 MP Front Camera
# 29    50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 37                108 MP Quad Rear & 40 MP Front Camera
# 49                108 MP Quad Rear & 32 MP Front Camera
# 69                       Foldable Display, Dual Display
# ...                                                 ...
# 996                      13 MP Rear & 5 MP Front Camera
# 1000                  1.77 inches, 240 x 320 px Display
# 1003                 8 MP Dual Rear & 5 MP Front Camera
# 1012                                   2 MP Rear Camera
# 1014                                   Foldable Display
#
#                                                    card  \
# 14                            Memory Card Not Supported
# 29                                          Android v13
# 37                                          Android v12
# 49                      Memory Card (Hybrid), upto 1 TB
# 69    64 MP + 10 MP + 8 MP Triple Rear & 32 MP Front...
# ...                                                 ...
# 996                               Memory Card Supported
# 1000                                       Dual Display
# 1003                  Memory Card (Hybrid), upto 512 GB
# 1012                                        Android v11
# 1014  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
#
#                               os
# 14                   Android v13
# 29                   No FM Radio
# 37                     Bluetooth
# 49                   Android v12
# 69                   Android v12
# ...                          ...
# 996   Android v6.0 (Marshmallow)
# 1000          1.3 MP Rear Camera
# 1003                 Android v12
# 1012                 No FM Radio
# 1014                 Android v12
#
# [141 rows x 11 columns]

# %%
# duplicate data

df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Overall Observations
#
# - There are around 1020 rows and 11 columns in the data.
# - There are no duplicate rows in the data.
# - There are a few missing values in the data in columns:
#     1. `rating`
#     2. `camera`
#     3. `card`
#     4. `os`
# - Remove feature phones from the data.

# %%
df.columns
# Out:
# Index(['model', 'price', 'rating', 'sim', 'processor', 'ram', 'battery',
#        'display', 'camera', 'card', 'os'],
#       dtype='object')

# %% [markdown]
# ## Column Wise Observations
#
# ### Model
#
# - The model column has two pieces of info.
#     1. Brand Name
#     2. Model Name
# - Row 15, 45, 50, 52 We have Ram and storage(in paranthesis) info along with model info - `Validation`
#
# ### Price
# - Rupee sign - `Validation`
# - Commas in values - `Validation`
#
# ### Rating
# - Missing values in column - 141 - `Completeness`
# - Ratings should be on the scale of 10 - `Consistency`
#
# ### Sim
# - We have to see the number of SIM's supported.
# - Bands Supported
# - Has Wifi
# - Has Extra features - (NFC, IR Blaster)
#
# ### Processor
# - Processor name
#     1. Brand Name
#     2. Model Name
# - Number of Cores - Str --> Integers
# - CPU speed given in GHz
#
# #### Row wise
#     - Row 120- tesla phone - Here only number of cores are given - `accuracy`
#     - Row 154 - Only Processor name is given - `consistency`
#     - Row 203 - Processor name is not given - `consistency`
#     - Row 584 - Data validation and inaccurate
#
# ### RAM
# - The first piece of info is about RAM.(in GB)
# - The second is about storage.(in GB)
#
# - Apple phone has only storage info.
#
# ### Battery
# 1. Size of the battery.
# 2. Fast charging present or not.
# 3. If FC then wattage.
#
# ### Display
# 1. Display size.
# 2. Resolution
# 3. Refresh Rate
# 4. Display shape
#
# - Apple phones have data shifting issues.
#
# ### Camera
# 1. Number of cameras.
# 2. Resolution of back cameras.
# 3. Resolution of front camera.
#
# ### Card
# 1. Is supported.
# 2. Sim Tray config
# 3. Size
#
# - Some rows have OS info in the memory card column.
#
# ### OS
# 1. OS --> Android iOS
# 2. Version

# %% [markdown]
# **Feature Phones**
#
# 1. Low priced. Lower than Rs.5000/-.
# 2. Small screen size - Less than 3 inch
# 3. Smaller battery capicities - Lower than 2000 mAh

# %%
df.sample(30)
# Out:
#                                            model    price  rating  \
# 146                                       iQOO 7  ₹24,990    83.0
# 124      Samsung Galaxy M33 5G (8GB RAM + 128GB)  ₹19,499    84.0
# 405                  Realme 9i (4GB RAM + 128GB)  ₹13,999    75.0
# 915                                     OPPO A15   ₹9,999    66.0
# 858                                  Oppo Reno 5  ₹29,990    83.0
# 316                                    Vivo Y100  ₹29,990    82.0
# 368   Samsung Galaxy S21 FE 5G (8GB RAM + 256GB)  ₹43,999    88.0
# 997                                     Poco C55   ₹7,999    70.0
# 879                                    Nokia X30  ₹41,990    85.0
# 219                          Samsung Galaxy A04e   ₹9,299    65.0
# 1004                     Motorola Edge 40 Fusion  ₹42,990    87.0
# 427                OPPO A55 4G (6GB RAM + 128GB)  ₹14,700    76.0
# 693                                  OPPO A97 5G  ₹23,990    79.0
# 207                        Samsung Galaxy A54 5G  ₹34,999    76.0
# 658                             Letv Y1 Pro Plus   ₹5,999    60.0
# 583                      Motorola Edge 40 Pro 5G  ₹59,990    89.0
# 407                              Vivo X80 Pro 5G  ₹79,999     NaN
# 300                                    Vivo Y01A   ₹7,790    60.0
# 372                                      Poco X3  ₹13,499    80.0
# 422                        Motorola Moto X30 Pro  ₹41,990     NaN
# 886                        Samsung Galaxy A92 5G  ₹47,990    80.0
# 347                             Oppo Find X6 Pro  ₹77,990     NaN
# 678                 Xiaomi Redmi Note 10 Pro Max  ₹19,999    81.0
# 279                  Realme C31 (4GB RAM + 64GB)   ₹8,999    65.0
# 514                               POCO M3 Pro 5G  ₹15,999    75.0
# 195                                   Realme C35  ₹11,828    70.0
# 1010     Realme Narzo 50i Prime (4GB RAM + 64GB)   ₹8,720    64.0
# 740                      OPPO Reno 6 Pro Plus 5G  ₹44,990    87.0
# 428                         Xiaomi Mi 11T Pro 5G  ₹34,990    86.0
# 629                             Sony Xperia 1 II  ₹69,999    89.0
#
#                                                     sim  \
# 146             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 124             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 405                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 915                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 858                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 316                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 368             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 997                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 879             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 219                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1004            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 427                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 693                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 207             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 658                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 583             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 407             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 300                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 372          Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 422             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 886                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 347             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 678          Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 279                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 514      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 195                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1010                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 740             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 428   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 629             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                              processor  \
# 146       Snapdragon 870, Octa Core, 3.2 GHz Processor
# 124         Exynos  1280, Octa Core, 2.4 GHz Processor
# 405      Snapdragon  680, Octa Core, 2.4 GHz Processor
# 915            Helio P35, Octa Core, 2.3 GHz Processor
# 858    Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 316       Dimensity  900, Octa Core, 2.4 GHz Processor
# 368         Exynos  2100, Octa Core, 2.9 GHz Processor
# 997             Helio  G85, Octa Core, 2 GHz Processor
# 879      Snapdragon  695, Octa Core, 2.2 GHz Processor
# 219            Helio P35, Octa Core, 2.3 GHz Processor
# 1004  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 427            Helio G35, Octa Core, 2.3 GHz Processor
# 693     Dimensity 810 5G, Octa Core, 2.4 GHz Processor
# 207                   Exynos 1380, Octa Core Processor
# 658           Tiger T610, Quad Core, 1.8 GHz Processor
# 583    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 407     Snapdragon  8 Gen1, Octa Core, 3 GHz Processor
# 300            Helio P35, Octa Core, 2.3 GHz Processor
# 372     Snapdragon  732G, Octa Core, 2.3 GHz Processor
# 422   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 886         Dimensity 1300, Octa Core, 3 GHz Processor
# 347    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 678     Snapdragon  732G, Octa Core, 2.3 GHz Processor
# 279          Tiger T612, Octa Core, 1.82 GHz Processor
# 514     Dimensity 700 5G, Octa Core, 2.2 GHz Processor
# 195          Tiger  T616, Octa Core, 1.8 GHz Processor
# 1010         Tiger T612, Octa Core, 1.82 GHz Processor
# 740       Snapdragon 870, Octa Core, 3.2 GHz Processor
# 428    Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 629    Snapdragon  865 , Octa Core, 2.84 GHz Processor
#
#                             ram                                   battery  \
# 146    8 GB RAM, 128 GB inbuilt   4400 mAh Battery with 66W Fast Charging
# 124    8 GB RAM, 128 GB inbuilt   6000 mAh Battery with 25W Fast Charging
# 405    4 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 915     3 GB RAM, 32 GB inbuilt                          4230 mAh Battery
# 858    8 GB RAM, 128 GB inbuilt   4300 mAh Battery with 65W Fast Charging
# 316    8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 66W Fast Charging
# 368    8 GB RAM, 256 GB inbuilt   4500 mAh Battery with 25W Fast Charging
# 997     4 GB RAM, 64 GB inbuilt                          5000 mAh Battery
# 879    6 GB RAM, 128 GB inbuilt   4200 mAh Battery with 33W Fast Charging
# 219     3 GB RAM, 32 GB inbuilt                          5000 mAh Battery
# 1004   8 GB RAM, 128 GB inbuilt   4500 mAh Battery with 68W Fast Charging
# 427    6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 18W Fast Charging
# 693   12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 207    6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 25W Fast Charging
# 658     6 GB RAM, 64 GB inbuilt   4000 mAh Battery with 10W Fast Charging
# 583    8 GB RAM, 128 GB inbuilt  4800 mAh Battery with 125W Fast Charging
# 407   12 GB RAM, 256 GB inbuilt   4700 mAh Battery with 80W Fast Charging
# 300     2 GB RAM, 32 GB inbuilt   5000 mAh Battery with 10W Fast Charging
# 372     6 GB RAM, 64 GB inbuilt   6000 mAh Battery with 33W Fast Charging
# 422    8 GB RAM, 128 GB inbuilt  4450 mAh Battery with 125W Fast Charging
# 886    8 GB RAM, 128 GB inbuilt       5000 mAh Battery with Fast Charging
# 347   12 GB RAM, 256 GB inbuilt  4700 mAh Battery with 120W Fast Charging
# 678     6 GB RAM, 64 GB inbuilt   5020 mAh Battery with 33W Fast Charging
# 279     4 GB RAM, 64 GB inbuilt                          5000 mAh Battery
# 514     4 GB RAM, 64 GB inbuilt   5000 mAh Battery with 18W Fast Charging
# 195     4 GB RAM, 64 GB inbuilt   5000 mAh Battery with 18W Fast Charging
# 1010    4 GB RAM, 64 GB inbuilt   5000 mAh Battery with 10W Fast Charging
# 740    8 GB RAM, 128 GB inbuilt   4500 mAh Battery with 65W Fast Charging
# 428    8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 120W Fast Charging
# 629    8 GB RAM, 256 GB inbuilt   4000 mAh Battery with 21W Fast Charging
#
#                                                 display  \
# 146   6.62 inches, 1080 x 2400 px, 120 Hz Display wi...
# 124   6.6 inches, 1080 x 2400 px, 120 Hz Display wit...
# 405   6.6 inches, 1080 x 2412 px, 90 Hz Display with...
# 915   6.52 inches, 720 x 1600 px Display with Water ...
# 858   6.43 inches, 1080 x 2400 px Display with Punch...
# 316   6 inches, 1080 x 2400 px, 120 Hz Display with ...
# 368   6.4 inches, 1080 x 2340 px, 120 Hz Display wit...
# 997   6.71 inches, 720 x 1650 px Display with Water ...
# 879   6.43 inches, 1080 x 2400 px, 90 Hz Display wit...
# 219   6.5 inches, 720 x 1600 px Display with Water D...
# 1004  6.67 inches, 1080 x 2400 px, 144 Hz Display wi...
# 427   6.51 inches, 720 x 1600 px Display with Punch ...
# 693   6.56 inches, 1080 x 2400 px, 90 Hz Display wit...
# 207   6.4 inches, 1080 x 2400 px, 120 Hz Display wit...
# 658   6.5 inches, 720 x 1560 px Display with Small N...
# 583   6.7 inches, 1080 x 2460 px, 165 Hz Display wit...
# 407   6.78 inches, 1440 x 3200 px, 120 Hz Display wi...
# 300   6.51 inches, 720 x 1600 px Display with Water ...
# 372   6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 422   6.67 inches, 1080 x 2400 px, 144 Hz Display wi...
# 886   6.7 inches, 1080 x 2400 px Display with Punch ...
# 347   6.78 inches, 1080 x 2400 px, 120 Hz Display wi...
# 678   6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 279   6.52 inches, 720 x 1600 px Display with Water ...
# 514   6.5 inches, 1080 x 2400 px, 90 Hz Display with...
# 195   6.6 inches, 1080 x 2408 px Display with Water ...
# 1010  6.5 inches, 720 x 1600 px Display with Water D...
# 740   6.55 inches, 1080 x 2400 px, 90 Hz Display wit...
# 428   6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 629                  6.5 inches, 1644 x 3840 px Display
#
#                                                  camera  \
# 146   48 MP + 13 MP + 2 MP Triple Rear & 16 MP Front...
# 124                 50 MP Quad Rear & 8 MP Front Camera
# 405   50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 915   13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 858                64 MP Quad Rear & 32 MP Front Camera
# 316   50 MP + 8 MP + 2 MP Triple Rear & 50 MP + 8 MP...
# 368   12 MP + 12 MP + 8 MP Triple Rear & 32 MP Front...
# 997   50 MP + Depth Sensor Dual Rear & 5 MP Front Ca...
# 879        50 MP + 13 MP Dual Rear & 16 MP Front Camera
# 219          13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 1004  50 MP + 13 MP + 2 MP Triple Rear & 32 MP Front...
# 427   50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 693          48 MP + 2 MP Dual Rear & 8 MP Front Camera
# 207   50 MP + 12 MP + 5 MP Triple Rear & 32 MP Front...
# 658   8 MP + Depth Sensor Dual Rear & 5 MP Front Camera
# 583   50 MP + 50 MP + 12 MP Triple Rear & 60 MP Fron...
# 407                50 MP Quad Rear & 32 MP Front Camera
# 300                       8 MP Rear & 5 MP Front Camera
# 372                64 MP Quad Rear & 20 MP Front Camera
# 422   200 MP + 50 MP + 12 MP Triple Rear & 60 MP Fro...
# 886   48 MP + 12 MP + 5 MP Triple Rear & 16 MP Front...
# 347   50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 678               108 MP Quad Rear & 16 MP Front Camera
# 279   13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...
# 514   48 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 195   50 MP + 2 MP + 0.3 MP Triple Rear & 8 MP Front...
# 1010                      8 MP Rear & 5 MP Front Camera
# 740                50 MP Quad Rear & 32 MP Front Camera
# 428   108 MP + 8 MP + 5 MP Triple Rear & 16 MP Front...
# 629                 12 MP Quad Rear & 8 MP Front Camera
#
#                                     card             os
# 146                          Android v11    No FM Radio
# 124     Memory Card Supported, upto 1 TB    Android v12
# 405     Memory Card Supported, upto 1 TB    Android v11
# 915   Memory Card Supported, upto 256 GB  Android v10.0
# 858                          Android v11      Bluetooth
# 316            Memory Card Not Supported    Android v12
# 368            Memory Card Not Supported    Android v11
# 997   Memory Card Supported, upto 512 GB    Android v12
# 879     Memory Card Supported, upto 1 TB    Android v12
# 219     Memory Card Supported, upto 1 TB    Android v12
# 1004           Memory Card Not Supported    Android v13
# 427   Memory Card Supported, upto 256 GB    Android v11
# 693     Memory Card Supported, upto 1 TB    Android v12
# 207     Memory Card Supported, upto 1 TB    Android v13
# 658                          Android v11    No FM Radio
# 583                          Android v12    No FM Radio
# 407            Memory Card Not Supported    Android v12
# 300                Memory Card Supported    Android v11
# 372    Memory Card (Hybrid), upto 512 GB    Android v10
# 422                          Android v12    No FM Radio
# 886            Memory Card Not Supported    Android v12
# 347                          Android v13    No FM Radio
# 678   Memory Card Supported, upto 512 GB    Android v11
# 279     Memory Card Supported, upto 1 TB    Android v11
# 514      Memory Card (Hybrid), upto 1 TB    Android v11
# 195     Memory Card Supported, upto 1 TB    Android v11
# 1010    Memory Card Supported, upto 1 TB    Android v11
# 740                          Android v11    No FM Radio
# 428                          Android v11    No FM Radio
# 629                 Memory Card (Hybrid)    Android v10

# %%
# remove feature phones from data

def extract_feature_phones(df: pd.DataFrame):
    temp_df = (
        df
        .assign(
            price=lambda df_: (
                df_["price"]
                .str.replace("₹", "")
                .str.replace(",", "")
                .astype(np.float64)
            ),
            battery = lambda df_: (
                df_["battery"]
                .str.extract("(\d+).?mAh")
                .astype(np.float64)
        ),
            display = lambda df_:(
                df_["display"]
                .str.extract("(\d+\.\d*).?inches")
                .astype(np.float64)
            )
        )
    )

    battery_cond = temp_df["battery"] <= 2000
    display_cond = temp_df["display"] <= 4.0
    price_cond = temp_df["price"] <= 4000


    return (
        temp_df
        .loc[(battery_cond) | (display_cond) | (price_cond)]
    )


extract_feature_phones(df)
# Out:
#                               model    price  rating  \
# 155                 Nokia 2780 Flip   4990.0     NaN
# 190                      Realme C2s   3499.0    63.0
# 191                  Duoqin F22 Pro   9990.0     NaN
# 271               Nokia 2720 V Flip   6199.0     NaN
# 400                  Jio JioPhone 2   2999.0     NaN
# 473                    Nokia 110 4G   1762.0     NaN
# 477                        Vivo Y25   7499.0     NaN
# 478                     Lyf Earth 1   3990.0    60.0
# 486                   Nokia 8000 4G   6899.0     NaN
# 532   Samsung Guru Music 2 Dual Sim   1949.0     NaN
# 533                 Itel MagicX Pro   2799.0     NaN
# 551                 itel Magic 2 4G   2399.0     NaN
# 573                Nokia 105 (2019)   1299.0     NaN
# 575                        Lyf C459   1999.0     NaN
# 582                   Nokia 8210 4G   3749.0     NaN
# 608               Namotel Achhe Din     99.0     NaN
# 611                 Eunity U1 5605N    699.0     NaN
# 627                    Nokia 225 4G   3589.0     NaN
# 640                  Nokia 105 Plus   1299.0     NaN
# 647               Motorola Moto A10   1339.0     NaN
# 656            Apple iPhone SE 2020  39900.0    63.0
# 657                   Zanco Tiny T1   2799.0     NaN
# 665                    itel it2163S    958.0     NaN
# 685                    Xiaomi Qin 1   1799.0     NaN
# 699           Samsung Guru GT-E1215   1850.0     NaN
# 748                    Nokia 400 4G   3290.0     NaN
# 757                    Karbonn KU3i    995.0     NaN
# 817                    itel Magic X   2239.0     NaN
# 835                  Eunity U1 King    599.0     NaN
# 844                    CAT S22 Flip  14999.0     NaN
# 846                   DIZO Star 500   1749.0     NaN
# 852                    Nokia 215 4G   3099.0     NaN
# 873              BlackZone Ultra 4G   1899.0     NaN
# 881                Nokia 110 (2022)   1599.0     NaN
# 907                    Itel A23 Pro   3999.0     NaN
# 917                Nokia 150 (2020)   2499.0     NaN
# 925                   Nokia 3310 4G   3999.0     NaN
# 926                     Lyf Earth 2   3890.0     NaN
# 927              Samsung Guru E1200   1685.0     NaN
# 930                iKall K88 Pro 4G   2099.0     NaN
# 932                  Eunity U1 Livo    649.0     NaN
# 988             Nokia 5310 Dual Sim   3399.0     NaN
# 1000                XTouch F40 Flip   1999.0     NaN
#
#                                       sim  \
# 155               Dual Sim, 3G, 4G, Wi-Fi
# 190        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 191        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 271        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 400        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 473               Dual Sim, 3G, 4G, VoLTE
# 477               Dual Sim, 3G, 4G, Wi-Fi
# 478        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 486               Dual Sim, 3G, 4G, Wi-Fi
# 532                              Dual Sim
# 533        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 551        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 573                            Single Sim
# 575        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 582                      Dual Sim, 3G, 4G
# 608                   Dual Sim, 3G, Wi-Fi
# 611                              Dual Sim
# 627               Dual Sim, 3G, 4G, VoLTE
# 640                              Dual Sim
# 647                              Dual Sim
# 656   Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 657                            Single Sim
# 665                              Dual Sim
# 685                       Dual Sim, Wi-Fi
# 699                            Single Sim
# 748            Dual Sim, 4G, VoLTE, Wi-Fi
# 757                              Dual Sim
# 817        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 835                              Dual Sim
# 844      Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 846                              Dual Sim
# 852               Dual Sim, 3G, 4G, VoLTE
# 873               Dual Sim, 3G, 4G, VoLTE
# 881                              Dual Sim
# 907               Dual Sim, 3G, 4G, Wi-Fi
# 917                              Dual Sim
# 925        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 926        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 927                            Single Sim
# 930               Dual Sim, 3G, 4G, VoLTE
# 932                              Dual Sim
# 988                              Dual Sim
# 1000                             Dual Sim
#
#                                               processor  \
# 155      Snapdragon QM215, Quad Core, 1.3 GHz Processor
# 190             Helio  P22 , Octa Core, 2 GHz Processor
# 191              Helio  G85, Octa Core, 2 GHz Processor
# 271       Snapdragon 205 , Dual Core, 1.1 GHz Processor
# 400                          Dual Core, 1 GHz Processor
# 473                                             No Wifi
# 477          Helio MT6580, Quad Core, 1.3 GHz Processor
# 478        Snapdragon 615, Octa Core, 1.5 GHz Processor
# 486       Snapdragon  210, Quad Core, 1.1 GHz Processor
# 532                                             No Wifi
# 533                                     1 GHz Processor
# 551                                               No 3G
# 573                                             No Wifi
# 575    Snapdragon MSM8909, Quad Core, 1.1 GHz Processor
# 582                                             No Wifi
# 608                              1 GB RAM, 4 GB inbuilt
# 611                                               No 3G
# 627                                         Unisoc T117
# 640                              4 MB RAM, 4 MB inbuilt
# 647                              4 MB RAM, 4 MB inbuilt
# 656           A13 Bionic, Hexa Core, 2.65 GHz Processor
# 657                            32 MB RAM, 32 MB inbuilt
# 665                              4 MB RAM, 4 MB inbuilt
# 685                                       Helio MT6260A
# 699                                     800 mAh Battery
# 748                                    2000 mAh Battery
# 757                            52 MB RAM, 32 MB inbuilt
# 817                                               No 3G
# 835                                  1.77 MHz Processor
# 844          Qualcomm 215, Quad Core, 1.3 GHz Processor
# 846                           SC6531E, 26 MHz Processor
# 852                                         Unisoc T117
# 873                        Single Core, 1 GHz Processor
# 881                                             No Wifi
# 907   Spreadtrum  SC9832E , Quad Core, 1.4 GHz Proce...
# 917                                             No Wifi
# 925                          256 MB RAM, 512 MB inbuilt
# 926    Snapdragon MSM8939, Octa Core, 1.5 GHz Processor
# 927                                             No Wifi
# 930                           48 MB RAM, 128 MB inbuilt
# 932                                  1.77 MHz Processor
# 988                             8 MB RAM, 16 MB inbuilt
# 1000                                              No 3G
#
#                                    ram  battery  display  \
# 155           4 GB RAM, 512 MB inbuilt   1450.0     2.70
# 190            3 GB RAM, 32 GB inbuilt   4000.0     6.10
# 191            4 GB RAM, 64 GB inbuilt   2150.0     3.54
# 271           512 MB RAM, 4 GB inbuilt   1500.0     2.80
# 400           512 MB RAM, 4 GB inbuilt   2000.0     2.40
# 473          128 MB RAM, 48 MB inbuilt   1020.0     1.80
# 477            1 GB RAM, 16 GB inbuilt   1900.0     4.50
# 478            3 GB RAM, 32 GB inbuilt   3500.0     5.50
# 486           512 MB RAM, 4 GB inbuilt   1500.0     2.80
# 532     Single Core, 208 MHz Processor    800.0      NaN
# 533          64 MB RAM, 128 MB inbuilt   2500.0     2.40
# 551                               T117      NaN      NaN
# 573             4 MB RAM, 4 MB inbuilt    800.0     1.77
# 575             1 GB RAM, 8 GB inbuilt   2000.0     4.50
# 582                        Unisoc T107      NaN      NaN
# 608                   1325 mAh Battery      NaN      NaN
# 611       Dual Core, 500 MHz Processor      NaN      NaN
# 627          64 MB RAM, 128 MB inbuilt   1150.0     2.40
# 640                    800 mAh Battery      NaN      NaN
# 647                   1750 mAh Battery      NaN      NaN
# 656            3 GB RAM, 64 GB inbuilt   1821.0     4.70
# 657                    200 mAh Battery      NaN      NaN
# 665                   1200 mAh Battery      NaN      NaN
# 685            8 MB RAM, 16 MB inbuilt   1480.0     2.80
# 699   1.5 inches, 120 x 120 px Display      NaN      NaN
# 748   2.4 inches, 240 x 320 px Display      NaN      NaN
# 757                   1000 mAh Battery      NaN      NaN
# 817                               T117      NaN      NaN
# 835           32 MB RAM, 32 MB inbuilt   1000.0     1.80
# 844            2 GB RAM, 16 GB inbuilt   2000.0      NaN
# 846           32 MB RAM, 32 MB inbuilt   1900.0     2.80
# 852          64 MB RAM, 128 MB inbuilt   1150.0     2.40
# 873           48 MB RAM, 48 MB inbuilt   2500.0     1.80
# 881             4 MB RAM, 4 MB inbuilt   1000.0     1.77
# 907             1 GB RAM, 8 GB inbuilt   2400.0      NaN
# 917                       4 MB inbuilt   1020.0     2.40
# 925                   1200 mAh Battery      NaN      NaN
# 926            3 GB RAM, 32 GB inbuilt   2500.0      NaN
# 927                    800 mAh Battery      NaN      NaN
# 930                   1800 mAh Battery      NaN      NaN
# 932           16 MB RAM, 16 MB inbuilt   1000.0     1.80
# 988                   1200 mAh Battery      NaN      NaN
# 1000                           No Wifi      NaN      NaN
#
#                                           camera  \
# 155                                 Dual Display
# 190   13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 191                8 MP Rear & 2 MP Front Camera
# 271                                 Dual Display
# 400              2 MP Rear & 0.3 MP Front Camera
# 473                           0.3 MP Rear Camera
# 477                5 MP Rear & 2 MP Front Camera
# 478   13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 486                             2 MP Rear Camera
# 532                               No Rear Camera
# 533                           0.3 MP Rear Camera
# 551             2.4 inches, 240 x 320 px Display
# 573                               No Rear Camera
# 575                5 MP Rear & 2 MP Front Camera
# 582             2.8 inches, 240 x 320 px Display
# 608                      Android v5.0 (Lollipop)
# 611             1.8 inches, 128 x 160 px Display
# 627                           0.3 MP Rear Camera
# 640            Memory Card Supported, upto 32 GB
# 647            Memory Card Supported, upto 32 GB
# 656               12 MP Rear & 7 MP Front Camera
# 657                                  No FM Radio
# 665            Memory Card Supported, upto 32 GB
# 685                               No Rear Camera
# 699                                          NaN
# 748                                    Bluetooth
# 757            Memory Card Supported, upto 16 GB
# 817             2.4 inches, 240 x 320 px Display
# 835                           0.3 MP Rear Camera
# 844                                 Dual Display
# 846                           0.3 MP Rear Camera
# 852                               No Rear Camera
# 873                             2 MP Rear Camera
# 881            Memory Card Supported, upto 32 GB
# 907                5 MP Rear & 2 MP Front Camera
# 917                           0.3 MP Rear Camera
# 925            Memory Card Supported, upto 32 GB
# 926              13 MP Rear & 13 MP Front Camera
# 927                                  No FM Radio
# 930           Memory Card Supported, upto 128 GB
# 932                           0.3 MP Rear Camera
# 988            Memory Card Supported, upto 32 GB
# 1000           1.77 inches, 240 x 320 px Display
#
#                                     card                                  os
# 155                     5 MP Rear Camera   Memory Card Supported, upto 32 GB
# 190   Memory Card Supported, upto 128 GB                  Android v9.0 (Pie)
# 191                Memory Card Supported                         Android v12
# 271                     2 MP Rear Camera               Memory Card Supported
# 400   Memory Card Supported, upto 128 GB                              KAI OS
# 473    Memory Card Supported, upto 32 GB                                 NaN
# 477   Memory Card Supported, upto 128 GB             Android v5.1 (Lollipop)
# 478     Memory Card (Hybrid), upto 64 GB           Android v5.1.1 (Lollipop)
# 486                Memory Card Supported                           Bluetooth
# 532    Memory Card Supported, upto 16 GB                                 NaN
# 533    Memory Card Supported, upto 64 GB                           Bluetooth
# 551                   1.3 MP Rear Camera   Memory Card Supported, upto 64 GB
# 573                                  NaN                                 NaN
# 575    Memory Card Supported, upto 32 GB          Android v6.0 (Marshmallow)
# 582                   0.3 MP Rear Camera   Memory Card Supported, upto 32 GB
# 608                            Bluetooth                                 NaN
# 611                   0.3 MP Rear Camera   Memory Card Supported, upto 16 GB
# 627    Memory Card Supported, upto 32 GB                   RTOS (Series 30+)
# 640                            Bluetooth                                 NaN
# 647                                  NaN                                 NaN
# 656                              iOS v13                         No FM Radio
# 657                            Bluetooth                                 NaN
# 665                            Bluetooth                                 NaN
# 685                              Nucleus                         No FM Radio
# 699                                  NaN                                 NaN
# 748                              Browser                                 NaN
# 757                            Bluetooth                                 NaN
# 817                   1.3 MP Rear Camera   Memory Card Supported, upto 64 GB
# 835                                  NaN                                 NaN
# 844        5 MP Rear & 2 MP Front Camera  Memory Card Supported, upto 128 GB
# 846    Memory Card Supported, upto 64 GB                           Bluetooth
# 852    Memory Card Supported, upto 32 GB                   RTOS (Series 30+)
# 873    Memory Card Supported, upto 48 GB                           Bluetooth
# 881                                  NaN                                 NaN
# 907                          Android v10                         No FM Radio
# 917    Memory Card Supported, upto 32 GB                           Bluetooth
# 925                            Bluetooth                             Browser
# 926     Memory Card (Hybrid), upto 64 GB           Android v5.1.1 (Lollipop)
# 927                                  NaN                                 NaN
# 930                            Bluetooth                             Browser
# 932                                  NaN                                 NaN
# 988                            Bluetooth                             Browser
# 1000                        Dual Display                  1.3 MP Rear Camera

# %%
df
# Out:
#                                 model    price  rating  \
# 0                       OnePlus 11 5G  ₹54,999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2               Samsung Galaxy A14 5G  ₹16,499    75.0
# 3                Motorola Moto G62 5G  ₹14,999    81.0
# 4                  Realme 10 Pro Plus  ₹24,999    82.0
# ...                               ...      ...     ...
# 1015       Motorola Moto Edge S30 Pro  ₹34,990    83.0
# 1016                      Honor X8 5G  ₹14,990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990    85.0
# 1018             Motorola Moto G91 5G  ₹19,990    80.0
# 1019           Samsung Galaxy M52s 5G  ₹24,990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                             processor  \
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
#                             ram                                    battery  \
# 0     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 100W Fast Charging
# 1      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 2       4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 15W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 4      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# ...                         ...                                        ...
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display  \
# 0     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera  \
# 0     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ...                                                 ...
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                                   card           os
# 0            Memory Card Not Supported  Android v13
# 1      Memory Card (Hybrid), upto 1 TB  Android v12
# 2     Memory Card Supported, upto 1 TB  Android v13
# 3      Memory Card (Hybrid), upto 1 TB  Android v12
# 4            Memory Card Not Supported  Android v13
# ...                                ...          ...
# 1015                       Android v12  No FM Radio
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1017         Memory Card Not Supported  Android v12
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12
#
# [1020 rows x 11 columns]

# %%
feature_phones_index = extract_feature_phones(df).index.to_list()

# %%
print(feature_phones_index)
print(len(feature_phones_index))
# Out:
# [155, 190, 191, 271, 400, 473, 477, 478, 486, 532, 533, 551, 573, 575, 582, 608, 611, 627, 640, 647, 656, 657, 665, 685, 699, 748, 757, 817, 835, 844, 846, 852, 873, 881, 907, 917, 925, 926, 927, 930, 932, 988, 1000]
# 43

# %%
def incomplete_data_phones(data: pd.DataFrame):

    columns_list = ["processor", "ram", "display"]

    temp_df = (
        data
        .assign(
            **{
                col: data[col].str.count(",")
                for col in columns_list
            }
        )
    )

    processor_split = 2
    ram_split = 1
    display_split = 2

    return (
        data
        .loc[(temp_df["processor"].lt(processor_split)) | \
        (temp_df["ram"].lt(ram_split)) | \
        (temp_df["display"].lt(display_split))]
    )



incomplete_data_phones(df)
# Out:
#                         model      price  rating  \
# 6             Apple iPhone 14    ₹65,999    81.0
# 15            Apple iPhone 13    ₹62,999    79.0
# 16                   Vivo Y16     ₹9,999    65.0
# 19                   Vivo Y22    ₹14,499    72.0
# 27    Apple iPhone 14 Pro Max  ₹1,29,990    76.0
# ...                       ...        ...     ...
# 1012                itel A23s     ₹4,787     NaN
# 1013       Google Pixel 8 Pro    ₹70,990    80.0
# 1016              Honor X8 5G    ₹14,990    75.0
# 1018     Motorola Moto G91 5G    ₹19,990    80.0
# 1019   Samsung Galaxy M52s 5G    ₹24,990    74.0
#
#                                           sim  \
# 6     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 15    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 16             Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 19             Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 27    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...                                       ...
# 1012                  Dual Sim, 3G, 4G, Wi-Fi
# 1013  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1016       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1018  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                               processor  \
# 6             Bionic A15, Hexa Core, 3.22 GHz Processor
# 15            Bionic A15, Hexa Core, 3.22 GHz Processor
# 16              Helio P35, Octa Core, 2.3 GHz Processor
# 19                Helio G70, Octa Core, 2 GHz Processor
# 27                     Bionic  A16, Hexa Core Processor
# ...                                                 ...
# 1012  Spreadtrum  SC9832E, Quad Core, 1.4 GHz Processor
# 1013              Google  Tensor 3, Octa Core Processor
# 1016     Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1018       Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                                Octa Core Processor
#
#                             ram                                    battery  \
# 6      6 GB RAM, 128 GB inbuilt        3279 mAh Battery with Fast Charging
# 15     4 GB RAM, 128 GB inbuilt        3240 mAh Battery with Fast Charging
# 16      3 GB RAM, 32 GB inbuilt    5000 mAh Battery with 10W Fast Charging
# 19      4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 18W Fast Charging
# 27     6 GB RAM, 128 GB inbuilt        4323 mAh Battery with Fast Charging
# ...                         ...                                        ...
# 1012    2 GB RAM, 32 GB inbuilt                           3020 mAh Battery
# 1013  12 GB RAM, 256 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display  \
# 6     6.1 inches, 1170 x 2532 px Display with Small ...
# 15    6.1 inches, 1170 x 2532 px Display with Small ...
# 16    6.51 inches, 720 x 1600 px Display with Water ...
# 19    6.55 inches, 720 x 1612 px Display with Water ...
# 27           6.7 inches, 1290 x 2796 px, 120 Hz Display
# ...                                                 ...
# 1012                     5 inches, 854 x 480 px Display
# 1013  6.73 inches, 1440 x 3120 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera  \
# 6          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 15         12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 16           13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 19           50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 27    48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# ...                                                 ...
# 1012                                   2 MP Rear Camera
# 1013  50 MP + 50 MP + 50 MP Triple Rear & 12 MP Fron...
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                                   card           os
# 6            Memory Card Not Supported      iOS v16
# 15           Memory Card Not Supported      iOS v15
# 16               Memory Card Supported  Android v12
# 19    Memory Card Supported, upto 1 TB  Android v12
# 27           Memory Card Not Supported      iOS v16
# ...                                ...          ...
# 1012                       Android v11  No FM Radio
# 1013                       Android v13  No FM Radio
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12
#
# [434 rows x 11 columns]

# %%
df.head(3)
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13

# %%
import re

# %%
def get_apple_phones(data: pd.DataFrame):
    return (
        data
        .loc[(
            data["model"]
            .str.contains("apple", flags=re.IGNORECASE)
        ), :]
    )

get_apple_phones(df)
# Out:
#                                model      price  rating  \
# 6                    Apple iPhone 14    ₹65,999    81.0
# 15                   Apple iPhone 13    ₹62,999    79.0
# 27           Apple iPhone 14 Pro Max  ₹1,29,990    76.0
# 33                   Apple iPhone 11    ₹38,999    73.0
# 56              Apple iPhone 14 Plus    ₹74,999    82.0
# 76               Apple iPhone 13 Pro  ₹1,19,900    83.0
# 100              Apple iPhone 14 Pro  ₹1,19,990    75.0
# 111                  Apple iPhone 12    ₹51,999    74.0
# 136          Apple iPhone 11 (128GB)    ₹46,999    75.0
# 149             Apple iPhone 12 Mini    ₹40,999    74.0
# 152          Apple iPhone 15 Pro Max  ₹1,42,990    79.0
# 162          Apple iPhone 13 Pro Max  ₹1,29,900    84.0
# 174                   Apple iPhone 9    ₹29,990    61.0
# 210  Apple iPhone 14 Pro Max (256GB)  ₹1,39,990    77.0
# 247          Apple iPhone 14 (256GB)    ₹75,999    82.0
# 263                 Apple iPhone XR2    ₹71,999    60.0
# 277             Apple iPhone 13 Mini    ₹64,900    79.0
# 282             Apple iPhone 14 Mini    ₹69,990    70.0
# 290    Apple iPhone 14 Pro Max (1TB)  ₹1,82,999    78.0
# 307          Apple iPhone 12 (128GB)    ₹55,999    75.0
# 323     Apple iPhone 14 Plus (256GB)    ₹84,999    83.0
# 346          Apple iPhone 13 (256GB)    ₹72,999    79.0
# 363     Apple iPhone 12 Mini (128GB)    ₹45,999    75.0
# 402            Apple iPhone 15 Ultra  ₹1,49,900    79.0
# 420      Apple iPhone 14 Pro (256GB)  ₹1,29,990    76.0
# 439           Apple iPhone SE 3 2022    ₹43,900     NaN
# 448              Apple iPhone 15 Pro  ₹1,30,990    75.0
# 527      Apple iPhone 13 Pro (256GB)  ₹1,29,900    83.0
# 606          Apple iPhone 11 Pro Max  ₹1,09,900    77.0
# 607                  Apple iPhone 7s    ₹52,990     NaN
# 628      Apple iPhone 12 Pro (512GB)  ₹1,39,900    80.0
# 636          Apple iPhone 14 (512GB)    ₹95,999    82.0
# 656             Apple iPhone SE 2020    ₹39,900    63.0
# 704  Apple iPhone 13 Pro Max (256GB)  ₹1,39,900    84.0
# 728                  Apple iPhone 15    ₹82,990    72.0
# 754       Apple iPod Touch (7th Gen)    ₹18,900     NaN
# 762                Apple iPhone SE 4    ₹49,990    60.0
# 764  Apple iPhone 14 Pro Max (512GB)  ₹1,69,900    78.0
# 781    Apple iPhone 13 Pro Max (1TB)  ₹1,79,900    86.0
# 813     Apple iPhone 14 Plus (512GB)  ₹1,04,999    83.0
# 814        Apple iPhone 14 Pro (1TB)  ₹1,72,999    77.0
# 840          Apple iPhone 13 (512GB)    ₹91,999    80.0
# 853      Apple iPhone 12 Pro (256GB)  ₹1,19,900    80.0
# 913     Apple iPhone 12 Mini (256GB)    ₹55,999    75.0
# 914          Apple iPhone 12 (256GB)    ₹67,999    76.0
# 928             Apple iPhone 15 Plus    ₹84,990    75.0
# 961        Apple iPhone 13 Pro (1TB)  ₹1,47,900    84.0
#
#                                                sim  \
# 6          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 15         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 27         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 33             Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 56         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 76         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 100        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 136            Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 149        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 152        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 162        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 174          Single Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 210        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 247        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 263            Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 277        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 282            Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 290        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 323        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 346        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 402        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 420        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 527        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 606            Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 607               Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 628        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 636        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 656            Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 704        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 728            Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 754                                          Wi-Fi
# 762        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 764        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 781        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 813        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 814        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 840        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 853        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 928  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 961        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                          processor  \
# 6        Bionic A15, Hexa Core, 3.22 GHz Processor
# 15       Bionic A15, Hexa Core, 3.22 GHz Processor
# 27                Bionic  A16, Hexa Core Processor
# 33       A13 Bionic, Hexa Core, 2.65 GHz Processor
# 56       Bionic A15, Hexa Core, 3.22 GHz Processor
# 76       Bionic A15, Hexa Core, 3.22 GHz Processor
# 100               Bionic  A16, Hexa Core Processor
# 111       Bionic A14, Hexa Core, 3.1 GHz Processor
# 136      A13 Bionic, Hexa Core, 2.65 GHz Processor
# 149       Bionic A14, Hexa Core, 3.1 GHz Processor
# 152                                    Bionic  A16
# 162      Bionic A15, Hexa Core, 3.22 GHz Processor
# 174      A13 Bionic, Hexa Core, 2.65 GHz Processor
# 210               Bionic  A16, Hexa Core Processor
# 247      Bionic A15, Hexa Core, 3.22 GHz Processor
# 263                                     Apple  A13
# 277      Bionic A15, Hexa Core, 3.22 GHz Processor
# 282                                     Bionic A16
# 290               Bionic  A16, Hexa Core Processor
# 307       Bionic A14, Hexa Core, 3.1 GHz Processor
# 323      Bionic A15, Hexa Core, 3.22 GHz Processor
# 346      Bionic A15, Hexa Core, 3.22 GHz Processor
# 363       Bionic A14, Hexa Core, 3.1 GHz Processor
# 402               Bionic  A17, Octa Core Processor
# 420               Bionic  A16, Hexa Core Processor
# 439     Bionic  A15, Hexa Core, 3.22 GHz Processor
# 448                                    Bionic  A16
# 527      Bionic A15, Hexa Core, 3.22 GHz Processor
# 606      A13 Bionic, Hexa Core, 2.65 GHz Processor
# 607  Fusion APL1024, Quad Core, 2.37 GHz Processor
# 628       Bionic A14, Hexa Core, 3.1 GHz Processor
# 636      Bionic A15, Hexa Core, 3.22 GHz Processor
# 656      A13 Bionic, Hexa Core, 2.65 GHz Processor
# 704      Bionic A15, Hexa Core, 3.22 GHz Processor
# 728                                    Bionic  A16
# 754                                  32 GB inbuilt
# 762     Bionic  A15, Hexa Core, 3.22 GHz Processor
# 764               Bionic  A16, Hexa Core Processor
# 781      Bionic A15, Hexa Core, 3.22 GHz Processor
# 813      Bionic A15, Hexa Core, 3.22 GHz Processor
# 814               Bionic  A16, Hexa Core Processor
# 840      Bionic A15, Hexa Core, 3.22 GHz Processor
# 853       Bionic A14, Hexa Core, 3.1 GHz Processor
# 913       Bionic A14, Hexa Core, 3.1 GHz Processor
# 914       Bionic A14, Hexa Core, 3.1 GHz Processor
# 928                Bionic A16, Hexa Core Processor
# 961      Bionic A15, Hexa Core, 3.22 GHz Processor
#
#                                  ram  \
# 6           6 GB RAM, 128 GB inbuilt
# 15          4 GB RAM, 128 GB inbuilt
# 27          6 GB RAM, 128 GB inbuilt
# 33           4 GB RAM, 64 GB inbuilt
# 56          6 GB RAM, 128 GB inbuilt
# 76          6 GB RAM, 128 GB inbuilt
# 100         6 GB RAM, 128 GB inbuilt
# 111          4 GB RAM, 64 GB inbuilt
# 136         4 GB RAM, 128 GB inbuilt
# 149          4 GB RAM, 64 GB inbuilt
# 152         8 GB RAM, 256 GB inbuilt
# 162         6 GB RAM, 128 GB inbuilt
# 174          3 GB RAM, 64 GB inbuilt
# 210         6 GB RAM, 256 GB inbuilt
# 247         6 GB RAM, 256 GB inbuilt
# 263          4 GB RAM, 64 GB inbuilt
# 277         4 GB RAM, 128 GB inbuilt
# 282         6 GB RAM, 128 GB inbuilt
# 290           6 GB RAM, 1 TB inbuilt
# 307         4 GB RAM, 128 GB inbuilt
# 323         6 GB RAM, 256 GB inbuilt
# 346         4 GB RAM, 256 GB inbuilt
# 363         4 GB RAM, 128 GB inbuilt
# 402         8 GB RAM, 128 GB inbuilt
# 420         6 GB RAM, 256 GB inbuilt
# 439                    64 GB inbuilt
# 448         8 GB RAM, 128 GB inbuilt
# 527         6 GB RAM, 256 GB inbuilt
# 606          4 GB RAM, 64 GB inbuilt
# 607          3 GB RAM, 32 GB inbuilt
# 628         6 GB RAM, 512 GB inbuilt
# 636         6 GB RAM, 512 GB inbuilt
# 656          3 GB RAM, 64 GB inbuilt
# 704         6 GB RAM, 256 GB inbuilt
# 728         6 GB RAM, 128 GB inbuilt
# 754  4 inches, 640 x 1136 px Display
# 762                    64 GB inbuilt
# 764         6 GB RAM, 512 GB inbuilt
# 781           6 GB RAM, 1 TB inbuilt
# 813         6 GB RAM, 512 GB inbuilt
# 814           6 GB RAM, 1 TB inbuilt
# 840         4 GB RAM, 512 GB inbuilt
# 853         6 GB RAM, 256 GB inbuilt
# 913         4 GB RAM, 256 GB inbuilt
# 914         4 GB RAM, 256 GB inbuilt
# 928         8 GB RAM, 128 GB inbuilt
# 961           6 GB RAM, 1 TB inbuilt
#
#                                                battery  \
# 6                  3279 mAh Battery with Fast Charging
# 15                 3240 mAh Battery with Fast Charging
# 27                 4323 mAh Battery with Fast Charging
# 33                                    3110 mAh Battery
# 56                 4325 mAh Battery with Fast Charging
# 76                 3095 mAh Battery with Fast Charging
# 100                3200 mAh Battery with Fast Charging
# 111  6.1 inches, 1170 x 2532 px Display with Large ...
# 136                                   3110 mAh Battery
# 149                 5.4 inches, 1080 x 2340 px Display
# 152            4352 mAh Battery with 25W Fast Charging
# 162                4352 mAh Battery with Fast Charging
# 174                2050 mAh Battery with Fast Charging
# 210                4323 mAh Battery with Fast Charging
# 247                3279 mAh Battery with Fast Charging
# 263                3060 mAh Battery with Fast Charging
# 277                2438 mAh Battery with Fast Charging
# 282                3500 mAh Battery with Fast Charging
# 290                4323 mAh Battery with Fast Charging
# 307  6.1 inches, 1170 x 2532 px Display with Large ...
# 323                4325 mAh Battery with Fast Charging
# 346                3240 mAh Battery with Fast Charging
# 363                 5.4 inches, 1080 x 2340 px Display
# 402                4700 mAh Battery with Fast Charging
# 420                3200 mAh Battery with Fast Charging
# 439                  4.7 inches, 750 x 1334 px Display
# 448  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 527                3095 mAh Battery with Fast Charging
# 606            3500 mAh Battery with 18W Fast Charging
# 607                                   2230 mAh Battery
# 628  6.1 inches, 1170 x 2532 px Display with Large ...
# 636                3279 mAh Battery with Fast Charging
# 656            1821 mAh Battery with 18W Fast Charging
# 704                4352 mAh Battery with Fast Charging
# 728                3285 mAh Battery with Fast Charging
# 754                    8 MP Rear & 1.2 MP Front Camera
# 762                  6.1 inches, 750 x 1580 px Display
# 764                4323 mAh Battery with Fast Charging
# 781                4352 mAh Battery with Fast Charging
# 813                4325 mAh Battery with Fast Charging
# 814                3200 mAh Battery with Fast Charging
# 840                3240 mAh Battery with Fast Charging
# 853  6.1 inches, 1170 x 2532 px Display with Large ...
# 913                 5.4 inches, 1080 x 2340 px Display
# 914  6.1 inches, 1170 x 2532 px Display with Large ...
# 928                4532 mAh Battery with Fast Charging
# 961                3095 mAh Battery with Fast Charging
#
#                                                display  \
# 6    6.1 inches, 1170 x 2532 px Display with Small ...
# 15   6.1 inches, 1170 x 2532 px Display with Small ...
# 27          6.7 inches, 1290 x 2796 px, 120 Hz Display
# 33   6.1 inches, 828 x 1792 px Display with Large N...
# 56   6.7 inches, 1284 x 2778 px Display with Small ...
# 76   6.1 inches, 1170 x 2532 px, 120 Hz Display wit...
# 100         6.1 inches, 1179 x 2556 px, 120 Hz Display
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 136  6.1 inches, 828 x 1792 px Display with Large N...
# 149       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 152  6.68 inches, 1284 x 2778 px, 120 Hz Display wi...
# 162  6.7 inches, 1284 x 2778 px, 120 Hz Display wit...
# 174  4.7 inches, 750 x 1334 px Display with Large N...
# 210         6.7 inches, 1290 x 2796 px, 120 Hz Display
# 247  6.1 inches, 1170 x 2532 px Display with Small ...
# 263                  6.1 inches, 828 x 1792 px Display
# 277  5.4 inches, 1080 x 2340 px Display with Large ...
# 282  5.42 inches, 1080 x 2340 px Display with Punch...
# 290         6.7 inches, 1290 x 2796 px, 120 Hz Display
# 307       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 323  6.7 inches, 1284 x 2778 px Display with Small ...
# 346  6.1 inches, 1170 x 2532 px Display with Small ...
# 363       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 402        6.73 inches, 1290 x 2796 px, 120 Hz Display
# 420         6.1 inches, 1179 x 2556 px, 120 Hz Display
# 439                     12 MP Rear & 7 MP Front Camera
# 448  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 527  6.1 inches, 1170 x 2532 px, 120 Hz Display wit...
# 606  6.5 inches, 1242 x 2688 px Display with Large ...
# 607                  4.7 inches, 750 x 1334 px Display
# 628  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 636  6.1 inches, 1170 x 2532 px Display with Small ...
# 656                  4.7 inches, 750 x 1334 px Display
# 704  6.7 inches, 1284 x 2778 px, 120 Hz Display wit...
# 728  6.06 inches, 1170 x 2532 px Display with Punch...
# 754                                            iOS v12
# 762                  12 MP Rear & 10.8 MP Front Camera
# 764         6.7 inches, 1290 x 2796 px, 120 Hz Display
# 781  6.7 inches, 1284 x 2778 px, 120 Hz Display wit...
# 813  6.7 inches, 1284 x 2778 px Display with Small ...
# 814         6.1 inches, 1179 x 2556 px, 120 Hz Display
# 840  6.1 inches, 1170 x 2532 px Display with Small ...
# 853  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 913       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 928  6.71 inches, 1284 x 2778 px, 120 Hz Display wi...
# 961  6.1 inches, 1170 x 2532 px, 120 Hz Display wit...
#
#                                                 camera  \
# 6         12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 15        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 27   48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 33        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 56        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 76   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 100  48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 111                          Memory Card Not Supported
# 136       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149                          Memory Card Not Supported
# 152  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 162  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 174                     12 MP Rear & 7 MP Front Camera
# 210  48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 247       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 263         12 MP + 5 MP Dual Rear & 7 MP Front Camera
# 277       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 282       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 290  48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 307                          Memory Card Not Supported
# 323       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 346       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 363                          Memory Card Not Supported
# 402  48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 420  48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 439                          Memory Card Not Supported
# 448                          Memory Card Not Supported
# 527  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 606  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 607                     13 MP Rear & 7 MP Front Camera
# 628                          Memory Card Not Supported
# 636       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 656                     12 MP Rear & 7 MP Front Camera
# 704  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 728       50 MP + 13 MP Dual Rear & 13 MP Front Camera
# 754                                        No FM Radio
# 762                          Memory Card Not Supported
# 764  48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 781  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 813       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 814  48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 840       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 853                          Memory Card Not Supported
# 913                          Memory Card Not Supported
# 914                          Memory Card Not Supported
# 928       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 961  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
#
#                           card           os
# 6    Memory Card Not Supported      iOS v16
# 15   Memory Card Not Supported      iOS v15
# 27   Memory Card Not Supported      iOS v16
# 33   Memory Card Not Supported      iOS v13
# 56   Memory Card Not Supported      iOS v16
# 76   Memory Card Not Supported    iOS v15.0
# 100  Memory Card Not Supported      iOS v16
# 111                    iOS v14  No FM Radio
# 136  Memory Card Not Supported      iOS v13
# 149                    iOS v14  No FM Radio
# 152  Memory Card Not Supported      iOS v15
# 162  Memory Card Not Supported      iOS v15
# 174  Memory Card Not Supported    iOS v13.0
# 210  Memory Card Not Supported      iOS v16
# 247  Memory Card Not Supported      iOS v16
# 263  Memory Card Not Supported    iOS v12.3
# 277  Memory Card Not Supported      iOS v15
# 282  Memory Card Not Supported      iOS v15
# 290  Memory Card Not Supported      iOS v16
# 307                    iOS v14  No FM Radio
# 323  Memory Card Not Supported      iOS v16
# 346  Memory Card Not Supported      iOS v15
# 363                    iOS v14  No FM Radio
# 402  Memory Card Not Supported      iOS v17
# 420  Memory Card Not Supported      iOS v16
# 439                    iOS v15  No FM Radio
# 448                    iOS v15  No FM Radio
# 527  Memory Card Not Supported    iOS v15.0
# 606  Memory Card Not Supported      iOS v13
# 607                    iOS v10  No FM Radio
# 628                  iOS v14.0  No FM Radio
# 636  Memory Card Not Supported      iOS v16
# 656                    iOS v13  No FM Radio
# 704  Memory Card Not Supported      iOS v15
# 728  Memory Card Not Supported      iOS v15
# 754                  Bluetooth      Browser
# 762                    iOS v16  No FM Radio
# 764  Memory Card Not Supported      iOS v16
# 781  Memory Card Not Supported      iOS v15
# 813  Memory Card Not Supported      iOS v16
# 814  Memory Card Not Supported      iOS v16
# 840  Memory Card Not Supported      iOS v15
# 853                  iOS v14.0  No FM Radio
# 913                    iOS v14  No FM Radio
# 914                    iOS v14  No FM Radio
# 928  Memory Card Not Supported      iOS v16
# 961  Memory Card Not Supported    iOS v15.0

# %%
get_apple_phones(df).shape
# Out:
# (47, 11)

# %%
def get_ipods(df: pd.DataFrame):
  return (
      df
      .loc[(
          df["model"]
          .str.contains("iPod", flags=re.IGNORECASE)
      ), :]
  )

get_ipods(df)
# Out:
#                           model    price  rating    sim      processor  \
# 754  Apple iPod Touch (7th Gen)  ₹18,900     NaN  Wi-Fi  32 GB inbuilt
#
#                                  ram                          battery  \
# 754  4 inches, 640 x 1136 px Display  8 MP Rear & 1.2 MP Front Camera
#
#      display       camera       card       os
# 754  iOS v12  No FM Radio  Bluetooth  Browser

# %%
~df.sample(10)["display"].str.contains("inches", flags=re.IGNORECASE)
# Out:
# 892    False
# 58     False
# 454    False
# 219    False
# 933    False
# 611     True
# 33     False
# 27     False
# 758    False
# 930     True
# Name: display, dtype: bool

# %%
def get_apple_shifted_phones(data: pd.DataFrame):
    apple_data = get_apple_phones(data)

    return (
        apple_data
        .loc[
            (~apple_data["display"].str.contains("inches", flags=re.IGNORECASE)) | \
            (~apple_data["camera"].str.contains("MP", flags=re.IGNORECASE)) | \
            (~apple_data["card"].str.contains("Card", flags=re.IGNORECASE))
        ]
    )


get_apple_shifted_phones(df)
# Out:
#                             model      price  rating  \
# 111               Apple iPhone 12    ₹51,999    74.0
# 149          Apple iPhone 12 Mini    ₹40,999    74.0
# 307       Apple iPhone 12 (128GB)    ₹55,999    75.0
# 363  Apple iPhone 12 Mini (128GB)    ₹45,999    75.0
# 439        Apple iPhone SE 3 2022    ₹43,900     NaN
# 448           Apple iPhone 15 Pro  ₹1,30,990    75.0
# 607               Apple iPhone 7s    ₹52,990     NaN
# 628   Apple iPhone 12 Pro (512GB)  ₹1,39,900    80.0
# 656          Apple iPhone SE 2020    ₹39,900    63.0
# 754    Apple iPod Touch (7th Gen)    ₹18,900     NaN
# 762             Apple iPhone SE 4    ₹49,990    60.0
# 853   Apple iPhone 12 Pro (256GB)  ₹1,19,900    80.0
# 913  Apple iPhone 12 Mini (256GB)    ₹55,999    75.0
# 914       Apple iPhone 12 (256GB)    ₹67,999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 607         Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 656      Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 754                                    Wi-Fi
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 853  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                          processor  \
# 111       Bionic A14, Hexa Core, 3.1 GHz Processor
# 149       Bionic A14, Hexa Core, 3.1 GHz Processor
# 307       Bionic A14, Hexa Core, 3.1 GHz Processor
# 363       Bionic A14, Hexa Core, 3.1 GHz Processor
# 439     Bionic  A15, Hexa Core, 3.22 GHz Processor
# 448                                    Bionic  A16
# 607  Fusion APL1024, Quad Core, 2.37 GHz Processor
# 628       Bionic A14, Hexa Core, 3.1 GHz Processor
# 656      A13 Bionic, Hexa Core, 2.65 GHz Processor
# 754                                  32 GB inbuilt
# 762     Bionic  A15, Hexa Core, 3.22 GHz Processor
# 853       Bionic A14, Hexa Core, 3.1 GHz Processor
# 913       Bionic A14, Hexa Core, 3.1 GHz Processor
# 914       Bionic A14, Hexa Core, 3.1 GHz Processor
#
#                                  ram  \
# 111          4 GB RAM, 64 GB inbuilt
# 149          4 GB RAM, 64 GB inbuilt
# 307         4 GB RAM, 128 GB inbuilt
# 363         4 GB RAM, 128 GB inbuilt
# 439                    64 GB inbuilt
# 448         8 GB RAM, 128 GB inbuilt
# 607          3 GB RAM, 32 GB inbuilt
# 628         6 GB RAM, 512 GB inbuilt
# 656          3 GB RAM, 64 GB inbuilt
# 754  4 inches, 640 x 1136 px Display
# 762                    64 GB inbuilt
# 853         6 GB RAM, 256 GB inbuilt
# 913         4 GB RAM, 256 GB inbuilt
# 914         4 GB RAM, 256 GB inbuilt
#
#                                                battery  \
# 111  6.1 inches, 1170 x 2532 px Display with Large ...
# 149                 5.4 inches, 1080 x 2340 px Display
# 307  6.1 inches, 1170 x 2532 px Display with Large ...
# 363                 5.4 inches, 1080 x 2340 px Display
# 439                  4.7 inches, 750 x 1334 px Display
# 448  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 607                                   2230 mAh Battery
# 628  6.1 inches, 1170 x 2532 px Display with Large ...
# 656            1821 mAh Battery with 18W Fast Charging
# 754                    8 MP Rear & 1.2 MP Front Camera
# 762                  6.1 inches, 750 x 1580 px Display
# 853  6.1 inches, 1170 x 2532 px Display with Large ...
# 913                 5.4 inches, 1080 x 2340 px Display
# 914  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                display  \
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 307       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 363       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 439                     12 MP Rear & 7 MP Front Camera
# 448  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 607                  4.7 inches, 750 x 1334 px Display
# 628  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 656                  4.7 inches, 750 x 1334 px Display
# 754                                            iOS v12
# 762                  12 MP Rear & 10.8 MP Front Camera
# 853  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 913       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914       12 MP + 12 MP Dual Rear & 12 MP Front Camera
#
#                              camera       card           os
# 111       Memory Card Not Supported    iOS v14  No FM Radio
# 149       Memory Card Not Supported    iOS v14  No FM Radio
# 307       Memory Card Not Supported    iOS v14  No FM Radio
# 363       Memory Card Not Supported    iOS v14  No FM Radio
# 439       Memory Card Not Supported    iOS v15  No FM Radio
# 448       Memory Card Not Supported    iOS v15  No FM Radio
# 607  13 MP Rear & 7 MP Front Camera    iOS v10  No FM Radio
# 628       Memory Card Not Supported  iOS v14.0  No FM Radio
# 656  12 MP Rear & 7 MP Front Camera    iOS v13  No FM Radio
# 754                     No FM Radio  Bluetooth      Browser
# 762       Memory Card Not Supported    iOS v16  No FM Radio
# 853       Memory Card Not Supported  iOS v14.0  No FM Radio
# 913       Memory Card Not Supported    iOS v14  No FM Radio
# 914       Memory Card Not Supported    iOS v14  No FM Radio

# %%
# remove feature phones from data

def remove_feature_phones(data: pd.DataFrame):

    temp_df = (
        data
        .drop(index=extract_feature_phones(data).index.to_list())
        .drop(index=get_ipods(data).index.to_list())
    )

    return temp_df

# %%
df_without_feature_phones = remove_feature_phones(df)

df_without_feature_phones.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
df_without_feature_phones.shape
# Out:
# (976, 11)

# %%
# duplicates

df_without_feature_phones.duplicated().sum()
# Out:
# np.int64(0)

# %%
# missing values

df_without_feature_phones.isna().sum()

df_without_feature_phones.loc[df_without_feature_phones["os"].isna()]
# Out:
#                model    price  rating                        sim  \
# 645  Nokia 2760 Flip   ₹5,490     NaN    Dual Sim, 3G, 4G, Wi-Fi
# 857      LG Folder 2  ₹11,999     NaN  Single Sim, 3G, 4G, Wi-Fi
#
#                   processor                               ram  \
# 645        1450 mAh Battery  3.6 inches, 240 x 320 px Display
# 857  1 GB RAM, 8 GB inbuilt                  1470 mAh Battery
#
#                               battery                            display  \
# 645     5 MP Rear & 5 MP Front Camera  Memory Card Supported, upto 32 GB
# 857  2.8 inches, 240 x 320 px Display                   2 MP Rear Camera
#
#                     camera       card   os
# 645             Kaios v3.0  Bluetooth  NaN
# 857  Memory Card Supported  Bluetooth  NaN

# %%
def get_shifted_phones(data: pd.DataFrame):

    return (
        data
        .loc[
            (~data["display"].str.contains("inches", flags=re.IGNORECASE)) | \
            (~data["camera"].str.contains("MP", flags=re.IGNORECASE)) | \
            (~data["card"].str.contains("Card", flags=re.IGNORECASE))
        ]
    )

# %%
get_shifted_phones(df_without_feature_phones)
# Out:
#                             model      price  rating  \
# 8                 Nothing Phone 1    ₹26,749    85.0
# 9              OnePlus Nord 2T 5G    ₹28,999    84.0
# 12    Xiaomi Redmi Note 12 Pro 5G    ₹24,762    79.0
# 17           OPPO Reno 9 Pro Plus    ₹45,999    86.0
# 18                 OnePlus 10R 5G    ₹32,999    86.0
# ...                           ...        ...     ...
# 1011                 Oppo Find X6    ₹69,990    89.0
# 1012                    itel A23s     ₹4,787     NaN
# 1013           Google Pixel 8 Pro    ₹70,990    80.0
# 1014                Vivo X Fold 2  ₹1,19,990     NaN
# 1015   Motorola Moto Edge S30 Pro    ₹34,990    83.0
#
#                                                  sim  \
# 8            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 9            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 12    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 17           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 18           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...                                              ...
# 1011         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1012                         Dual Sim, 3G, 4G, Wi-Fi
# 1013         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1014         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1015              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                               processor  \
# 8     Snapdragon 778G Plus, Octa Core, 2.5 GHz Proce...
# 9           Dimensity  1300, Octa Core, 3 GHz Processor
# 12         Dimensity 1080, Octa Core, 2.6 GHz Processor
# 17     Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 18    Dimensity 8100 Max, Octa Core, 2.85 GHz Processor
# ...                                                 ...
# 1011    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1012  Spreadtrum  SC9832E, Quad Core, 1.4 GHz Processor
# 1013              Google  Tensor 3, Octa Core Processor
# 1014    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1015      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
#
#                             ram                                    battery  \
# 8      8 GB RAM, 128 GB inbuilt    4500 mAh Battery with 33W Fast Charging
# 9      8 GB RAM, 128 GB inbuilt    4500 mAh Battery with 80W Fast Charging
# 12     6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# 17    16 GB RAM, 256 GB inbuilt    4700 mAh Battery with 80W Fast Charging
# 18     8 GB RAM, 128 GB inbuilt    5000 mAh Battery with 80W Fast Charging
# ...                         ...                                        ...
# 1011   8 GB RAM, 256 GB inbuilt   4700 mAh Battery with 120W Fast Charging
# 1012    2 GB RAM, 32 GB inbuilt                           3020 mAh Battery
# 1013  12 GB RAM, 256 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# 1014  12 GB RAM, 256 GB inbuilt    4800 mAh Battery with 66W Fast Charging
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
#
#                                                 display  \
# 8     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 9     6.43 inches, 1080 x 2400 px, 90 Hz Display wit...
# 12    6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 17    6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 18    6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1011  6.73 inches, 1080 x 2400 px, 120 Hz Display wi...
# 1012                     5 inches, 854 x 480 px Display
# 1013  6.73 inches, 1440 x 3120 px, 120 Hz Display wi...
# 1014        8.03 inches, 1916 x 2160 px, 120 Hz Display
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
#
#                                                  camera  \
# 8          50 MP + 50 MP Dual Rear & 16 MP Front Camera
# 9     50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 12    50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 17    50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 18    50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# ...                                                 ...
# 1011  50 MP + 48 MP + 32 MP Triple Rear & 32 MP Fron...
# 1012                                   2 MP Rear Camera
# 1013  50 MP + 50 MP + 50 MP Triple Rear & 12 MP Fron...
# 1014                                   Foldable Display
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
#
#                                                    card           os
# 8                                           Android v12  No FM Radio
# 9                                           Android v12  No FM Radio
# 12                                          Android v12  No FM Radio
# 17                                          Android v13  No FM Radio
# 18                                          Android v12    Bluetooth
# ...                                                 ...          ...
# 1011                                        Android v12  No FM Radio
# 1012                                        Android v11  No FM Radio
# 1013                                        Android v13  No FM Radio
# 1014  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...  Android v12
# 1015                                        Android v12  No FM Radio
#
# [251 rows x 11 columns]

# %%
def get_left_shifted_phones(data: pd.DataFrame):

    return (
        data
        .loc[
            ~((data["os"].str.contains("Android", flags=re.IGNORECASE)) | \
             (data["os"].str.contains("iOS", flags=re.IGNORECASE)))
        ]
    )

get_left_shifted_phones(df_without_feature_phones)
# Out:
#                             model    price  rating  \
# 8                 Nothing Phone 1  ₹26,749    85.0
# 9              OnePlus Nord 2T 5G  ₹28,999    84.0
# 12    Xiaomi Redmi Note 12 Pro 5G  ₹24,762    79.0
# 17           OPPO Reno 9 Pro Plus  ₹45,999    86.0
# 18                 OnePlus 10R 5G  ₹32,999    86.0
# ...                           ...      ...     ...
# 1009                Xiaomi Civi 3  ₹32,990    86.0
# 1011                 Oppo Find X6  ₹69,990    89.0
# 1012                    itel A23s   ₹4,787     NaN
# 1013           Google Pixel 8 Pro  ₹70,990    80.0
# 1015   Motorola Moto Edge S30 Pro  ₹34,990    83.0
#
#                                                     sim  \
# 8               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 9               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 12       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 17              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 18              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...                                                 ...
# 1009  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1011            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1012                            Dual Sim, 3G, 4G, Wi-Fi
# 1013            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                               processor  \
# 8     Snapdragon 778G Plus, Octa Core, 2.5 GHz Proce...
# 9           Dimensity  1300, Octa Core, 3 GHz Processor
# 12         Dimensity 1080, Octa Core, 2.6 GHz Processor
# 17     Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 18    Dimensity 8100 Max, Octa Core, 2.85 GHz Processor
# ...                                                 ...
# 1009       Dimensity 8200, Octa Core, 3.1 GHz Processor
# 1011    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1012  Spreadtrum  SC9832E, Quad Core, 1.4 GHz Processor
# 1013              Google  Tensor 3, Octa Core Processor
# 1015      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
#
#                             ram                                    battery  \
# 8      8 GB RAM, 128 GB inbuilt    4500 mAh Battery with 33W Fast Charging
# 9      8 GB RAM, 128 GB inbuilt    4500 mAh Battery with 80W Fast Charging
# 12     6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# 17    16 GB RAM, 256 GB inbuilt    4700 mAh Battery with 80W Fast Charging
# 18     8 GB RAM, 128 GB inbuilt    5000 mAh Battery with 80W Fast Charging
# ...                         ...                                        ...
# 1009   8 GB RAM, 256 GB inbuilt    5000 mAh Battery with 80W Fast Charging
# 1011   8 GB RAM, 256 GB inbuilt   4700 mAh Battery with 120W Fast Charging
# 1012    2 GB RAM, 32 GB inbuilt                           3020 mAh Battery
# 1013  12 GB RAM, 256 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
#
#                                                 display  \
# 8     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 9     6.43 inches, 1080 x 2400 px, 90 Hz Display wit...
# 12    6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 17    6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 18    6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1009  6.7 inches, 1080 x 2400 px, 120 Hz Display wit...
# 1011  6.73 inches, 1080 x 2400 px, 120 Hz Display wi...
# 1012                     5 inches, 854 x 480 px Display
# 1013  6.73 inches, 1440 x 3120 px, 120 Hz Display wi...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
#
#                                                  camera         card  \
# 8          50 MP + 50 MP Dual Rear & 16 MP Front Camera  Android v12
# 9     50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...  Android v12
# 12    50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...  Android v12
# 17    50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...  Android v13
# 18    50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...  Android v12
# ...                                                 ...          ...
# 1009  64 MP + 20 MP + 2 MP Triple Rear & 32 MP + 32 ...  Android v13
# 1011  50 MP + 48 MP + 32 MP Triple Rear & 32 MP Fron...  Android v12
# 1012                                   2 MP Rear Camera  Android v11
# 1013  50 MP + 50 MP + 50 MP Triple Rear & 12 MP Fron...  Android v13
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...  Android v12
#
#                os
# 8     No FM Radio
# 9     No FM Radio
# 12    No FM Radio
# 17    No FM Radio
# 18      Bluetooth
# ...           ...
# 1009  No FM Radio
# 1011  No FM Radio
# 1012  No FM Radio
# 1013  No FM Radio
# 1015  No FM Radio
#
# [247 rows x 11 columns]

# %% [markdown]
# **Subset of Data**:
#
# Things to remove:
# 1. feature phones & ipods --> completed
# 2. shifted phones
# 3. incomplete data

# %%
indexes_of_shifted_phones = get_shifted_phones(df_without_feature_phones).index.to_list()

len(indexes_of_shifted_phones)
# Out:
# 251

# %%
indexes_of_incomplete_data = incomplete_data_phones(df_without_feature_phones).index.to_list()

len(indexes_of_incomplete_data)
# Out:
# 390

# %%
indexes_to_drop = set(indexes_of_shifted_phones)

# %%
len(indexes_to_drop)
# Out:
# 251

# %%
final_df = df_without_feature_phones.drop(index=indexes_to_drop)

final_df.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
final_df.shape
# Out:
# (725, 11)

# %%
725 / 1020
# Out:
# 0.7107843137254902

# %% [markdown]
# ## Column Wise Cleaning

# %% [markdown]
# ### Model

# %%
df.columns
# Out:
# Index(['model', 'price', 'rating', 'sim', 'processor', 'ram', 'battery',
#        'display', 'camera', 'card', 'os'],
#       dtype='object')

# %%
final_df["model"]
# Out:
# 0                                 OnePlus 11 5G
# 1                     OnePlus Nord CE 2 Lite 5G
# 2                         Samsung Galaxy A14 5G
# 3                          Motorola Moto G62 5G
# 4                            Realme 10 Pro Plus
#                          ...
# 1010    Realme Narzo 50i Prime (4GB RAM + 64GB)
# 1016                                Honor X8 5G
# 1017            POCO X4 GT 5G (8GB RAM + 256GB)
# 1018                       Motorola Moto G91 5G
# 1019                     Samsung Galaxy M52s 5G
# Name: model, Length: 725, dtype: object

# %%
# separated out brand and model_name from model

(
    final_df["model"]
    .str.split(" ", n=1, expand=True)
    .set_axis(labels=["brand", "model_name"], axis=1)
    .assign(
        model_name=lambda df_: df_["model_name"].str.replace("\(.+\)", "", regex=True)
        )
)
# Out:
#          brand         model_name
# 0      OnePlus              11 5G
# 1      OnePlus  Nord CE 2 Lite 5G
# 2      Samsung      Galaxy A14 5G
# 3     Motorola        Moto G62 5G
# 4       Realme        10 Pro Plus
# ...        ...                ...
# 1010    Realme   Narzo 50i Prime
# 1016     Honor              X8 5G
# 1017      POCO          X4 GT 5G
# 1018  Motorola        Moto G91 5G
# 1019   Samsung     Galaxy M52s 5G
#
# [725 rows x 2 columns]

# %%
(
    final_df["model"]
    .str.split(" ", n=1, expand=True)
    .set_axis(labels=["brand", "model_name"], axis=1)
    .assign(
        model_name=lambda df_: df_["model_name"].str.replace("\(.+\)", "", regex=True)
        )
    .loc[:, "brand"]
    .str.title()
    .unique()
)
# Out:
# array(['Oneplus', 'Samsung', 'Motorola', 'Realme', 'Apple', 'Xiaomi',
#        'Oppo', 'Vivo', 'Poco', 'Jio', 'Iqoo', 'Gionee', 'Tesla', 'Google',
#        'Infinix', 'Cola', 'Tecno', 'Ikall', 'Nokia', 'Lava', 'Redmi',
#        'Asus', 'Itel', 'Sony', 'Oukitel', 'Vertu', 'Blu', 'Huawei',
#        'Micromax', 'Lg', 'Honor', 'Leitz', 'Doogee', 'Zte', 'Tcl',
#        'Sharp', 'Blackview'], dtype=object)

# %%
(
    final_df["model"]
    .str.split(" ", n=1, expand=True)
    .set_axis(labels=["brand", "model_name"], axis=1)
    .assign(
        model_name=lambda df_: df_["model_name"].str.replace("\(.+\)", "", regex=True)
        )
    .loc[:,"model_name"]
    .str.contains("[\(\)]", regex=True)
    .sum()
)
# Out:
# np.int64(0)

# %%
def clean_model(ser:pd.Series) -> pd.DataFrame:
    return (
            ser
            .str.split(" ", n=1, expand=True)
            .set_axis(labels=["brand", "model_name"], axis=1)
            .assign(
                    model_name=lambda df_: (df_["model_name"]
                                            .str.replace("\(.+\)", "", regex=True)
                                            .str.strip()),
                    brand=lambda df_: df_["brand"].str.title().str.strip().str.title()
                    )
    )

# %%
clean_model(final_df["model"])
# Out:
#          brand         model_name
# 0      Oneplus              11 5G
# 1      Oneplus  Nord CE 2 Lite 5G
# 2      Samsung      Galaxy A14 5G
# 3     Motorola        Moto G62 5G
# 4       Realme        10 Pro Plus
# ...        ...                ...
# 1010    Realme    Narzo 50i Prime
# 1016     Honor              X8 5G
# 1017      Poco           X4 GT 5G
# 1018  Motorola        Moto G91 5G
# 1019   Samsung     Galaxy M52s 5G
#
# [725 rows x 2 columns]

# %%
clean_model(final_df["model"]).loc[:,"brand"].unique()
# Out:
# array(['Oneplus', 'Samsung', 'Motorola', 'Realme', 'Apple', 'Xiaomi',
#        'Oppo', 'Vivo', 'Poco', 'Jio', 'Iqoo', 'Gionee', 'Tesla', 'Google',
#        'Infinix', 'Cola', 'Tecno', 'Ikall', 'Nokia', 'Lava', 'Redmi',
#        'Asus', 'Itel', 'Sony', 'Oukitel', 'Vertu', 'Blu', 'Huawei',
#        'Micromax', 'Lg', 'Honor', 'Leitz', 'Doogee', 'Zte', 'Tcl',
#        'Sharp', 'Blackview'], dtype=object)

# %% [markdown]
# ### Price

# %%
final_df["price"]
# Out:
# 0       ₹54,999
# 1       ₹19,989
# 2       ₹16,499
# 3       ₹14,999
# 4       ₹24,999
#          ...
# 1010     ₹8,720
# 1016    ₹14,990
# 1017    ₹28,990
# 1018    ₹19,990
# 1019    ₹24,990
# Name: price, Length: 725, dtype: object

# %%
def clean_price(ser):

    return (
        ser
        .str.replace("₹", "")
        .str.replace(",", "")
        .astype(np.float64)
    )

# %%
type(clean_price(final_df["price"].sample(10)))
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Rating

# %%
final_df["rating"]
# Out:
# 0       89.0
# 1       81.0
# 2       75.0
# 3       81.0
# 4       82.0
#         ...
# 1010    64.0
# 1016    75.0
# 1017    85.0
# 1018    80.0
# 1019    74.0
# Name: rating, Length: 725, dtype: float64

# %%
# missing values in rating

final_df["rating"].isna().sum()
# Out:
# np.int64(49)

# %%
final_df[final_df["rating"].isna()]
# Out:
#                                         model      price  rating  \
# 14                Samsung Galaxy S23 Ultra 5G  ₹1,14,990     NaN
# 49                      Samsung Galaxy A74 5G    ₹42,999     NaN
# 75                             Gionee G13 Pro     ₹6,190     NaN
# 89                      Samsung Galaxy A73 5G    ₹41,999     NaN
# 105                          Xiaomi 13 Pro 5G    ₹58,990     NaN
# 114                           Xiaomi Redmi A1     ₹6,171     NaN
# 143                               Jio Phone 3     ₹4,499     NaN
# 156                                Realme C30     ₹5,299     NaN
# 193                              Nokia N73 5G    ₹46,999     NaN
# 225                                  Vivo Y02     ₹8,999     NaN
# 315                              itel S16 Pro     ₹6,990     NaN
# 333   Samsung Galaxy A73 5G (8GB RAM + 256GB)    ₹41,990     NaN
# 337                   Samsung Galaxy A03 Core     ₹6,499     NaN
# 348                           Vivo X90 Pro 5G    ₹56,999     NaN
# 352                         Jio JioPhone Next     ₹4,649     NaN
# 355                               Realme C30s     ₹7,145     NaN
# 370                         Sony Xperia Pro-I  ₹1,34,999     NaN
# 403                                  Poco C50     ₹6,499     NaN
# 404           Samsung Galaxy Note 30 Ultra 5G  ₹1,04,999     NaN
# 407                           Vivo X80 Pro 5G    ₹79,999     NaN
# 447                        Infinix Smart 6 HD     ₹6,999     NaN
# 462                       Xiaomi Mi Mix Alpha  ₹1,99,990     NaN
# 471                          Realme Narzo 50i     ₹6,490     NaN
# 480                           Tecno Pop 6 Pro     ₹6,299     NaN
# 481                              Itel A24 Pro     ₹5,990     NaN
# 489       Sony Xperia 1 IV (12GB RAM + 512GB)    ₹92,980     NaN
# 550                          Nokia X60 Pro 5G    ₹49,990     NaN
# 574                                  Vivo Y71    ₹25,000     NaN
# 597        Jio JioPhone Next (3GB RAM + 32GB)     ₹7,499     NaN
# 605               Samsung Galaxy S20 Ultra 5G    ₹99,999     NaN
# 649                     Huawei Mate 40 Pro 4G    ₹69,990     NaN
# 689                 Vivo Y02 (2GB RAM + 32GB)     ₹7,999     NaN
# 690            itel Vision 3 (2GB RAM + 32GB)     ₹5,785     NaN
# 735                            Tecno Pop 5 Go     ₹6,999     NaN
# 736                         Huawei P50 Pro 4G    ₹60,999     NaN
# 738                            Nokia C01 Plus     ₹5,249     NaN
# 744                                  itel S16     ₹5,990     NaN
# 794                                  itel A56     ₹5,490     NaN
# 800                            Huawei P40 Pro    ₹82,990     NaN
# 838                                Gionee K10     ₹6,999     NaN
# 856                   Samsung Galaxy A01 Core     ₹4,999     NaN
# 861                                 Vivo Y91c     ₹8,199     NaN
# 920                Samsung Galaxy S20 Plus 5G    ₹85,990     NaN
# 923                                 Realme A1     ₹8,999     NaN
# 983            itel Vision 1 (3GB RAM + 32GB)     ₹5,890     NaN
# 990          Huawei Mate 30 RS Porsche Design  ₹2,14,990     NaN
# 992                                 Realme C2     ₹6,999     NaN
# 996                                 Vivo Y55S    ₹13,490     NaN
# 1003                                  Lava X3     ₹6,999     NaN
#
#                                                     sim  \
# 14        Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 49              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 75                       Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 89              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 105   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 114                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 143                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 156                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 193                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 225                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 315                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 333             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 337                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 348   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 352                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 355                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 370             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 403                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 404             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 407             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 447                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 462                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 471                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 480                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 481                             Dual Sim, 3G, 4G, Wi-Fi
# 489             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 550                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 574                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 597                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 605             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 649     Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 689                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 690                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 735                                 Dual Sim, 3G, Wi-Fi
# 736     Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 738                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 744                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 794                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 800             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 838                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 856                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 861                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 920             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 923                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 983                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 990   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 992                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 996                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1003                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
#
#                                               processor  \
# 14      Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 49     Snapdragon 7 Gen1, Octa Core, 2.36 GHz Processor
# 75              Tiger  T310, Quad Core, 2 GHz Processor
# 89        Snapdragon 778G, Octa Core, 2.4 GHz Processor
# 105     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 114               Helio A22, Quad Core, 2 GHz Processor
# 143                        Quad Core, 1.4 GHz Processor
# 156           Tiger T612, Octa Core, 1.82 GHz Processor
# 193      Snapdragon  8 Gen1, Octa Core, 3 GHz Processor
# 225                          Helio, Octa Core Processor
# 315                        Quad Core, 1.3 GHz Processor
# 333       Snapdragon 778G, Octa Core, 2.4 GHz Processor
# 337       Unisoc  SC9836A, Quad Core, 1.6 GHz Processor
# 348       Dimensity 9200, Octa Core, 3.05 GHz Processor
# 352          Qualcomm 215, Quad Core, 1.3 GHz Processor
# 355        Unisoc SC9863A, Octa Core, 1.6 GHz Processor
# 370       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 403               Helio A22, Quad Core, 2 GHz Processor
# 404   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 407      Snapdragon  8 Gen1, Octa Core, 3 GHz Processor
# 447               Helio A22, Quad Core, 2 GHz Processor
# 462      Snapdragon 855+, Octa Core, 2.96 GHz Processor
# 471       Unisoc  SC9863A, Octa Core, 1.6 GHz Processor
# 480               Helio A22, Quad Core, 2 GHz Processor
# 481       Unisoc  SC9832E, Quad Core, 1.4 GHz Processor
# 489       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 550       Snapdragon  870, Octa Core, 3.2 GHz Processor
# 574        Snapdragon 425, Quad Core, 1.4 GHz Processor
# 597          Qualcomm 215, Quad Core, 1.3 GHz Processor
# 605           Exynos 990, Octa Core, 2.73 GHz Processor
# 649          Kirin  9000, Octa Core, 3.13 GHz Processor
# 689                          Helio, Octa Core Processor
# 690       Unisoc  SC9863a, Octa Core, 1.6 GHz Processor
# 735    Spreadtrum  SC7731, Quad Core, 1.3 GHz Processor
# 736       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 738       Unisoc  SC9863A, Octa Core, 1.6 GHz Processor
# 744        Unisoc SC7731E, Quad Core, 1.3 GHz Processor
# 794                        Quad Core, 1.3 GHz Processor
# 800            Kirin 990, Octa Core, 2.86 GHz Processor
# 838             Tiger  T310, Quad Core, 2 GHz Processor
# 856               (28 nm), Quad Core, 1.5 GHz Processor
# 861               Helio P22, Octa Core, 2 GHz Processor
# 920           Exynos 990, Octa Core, 2.73 GHz Processor
# 923             Helio P70, Octa Core, 2.1 GHz Processor
# 983           Unisoc  A55, Octa Core, 1.6 GHz Processor
# 990           Kirin  990, Octa Core, 2.86 GHz Processor
# 992               Helio P22, Octa Core, 2 GHz Processor
# 996        Snapdragon 425, Quad Core, 1.2 GHz Processor
# 1003              Helio A22, Quad Core, 2 GHz Processor
#
#                             ram                                   battery  \
# 14     8 GB RAM, 256 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 49     8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 75      4 GB RAM, 32 GB inbuilt                          3500 mAh Battery
# 89     8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 25W Fast Charging
# 105    8 GB RAM, 128 GB inbuilt  4820 mAh Battery with 120W Fast Charging
# 114     2 GB RAM, 32 GB inbuilt   5000 mAh Battery with 10W Fast Charging
# 143     2 GB RAM, 64 GB inbuilt                          2800 mAh Battery
# 156     2 GB RAM, 32 GB inbuilt                          5000 mAh Battery
# 193   12 GB RAM, 256 GB inbuilt   6000 mAh Battery with 65W Fast Charging
# 225     3 GB RAM, 32 GB inbuilt   5000 mAh Battery with 10W Fast Charging
# 315     2 GB RAM, 32 GB inbuilt                          4000 mAh Battery
# 333    8 GB RAM, 256 GB inbuilt   5000 mAh Battery with 25W Fast Charging
# 337     2 GB RAM, 32 GB inbuilt                          5000 mAh Battery
# 348    8 GB RAM, 256 GB inbuilt  4870 mAh Battery with 120W Fast Charging
# 352     2 GB RAM, 32 GB inbuilt                          3500 mAh Battery
# 355     2 GB RAM, 32 GB inbuilt   5000 mAh Battery with 10W Fast Charging
# 370   12 GB RAM, 512 GB inbuilt   4500 mAh Battery with 30W Fast Charging
# 403     2 GB RAM, 32 GB inbuilt   5000 mAh Battery with 10W Fast Charging
# 404   12 GB RAM, 256 GB inbuilt   4500 mAh Battery with 67W Fast Charging
# 407   12 GB RAM, 256 GB inbuilt   4700 mAh Battery with 80W Fast Charging
# 447     2 GB RAM, 32 GB inbuilt                          5000 mAh Battery
# 462   12 GB RAM, 512 GB inbuilt   4050 mAh Battery with 40W Fast Charging
# 471     2 GB RAM, 32 GB inbuilt                          5000 mAh Battery
# 480     2 GB RAM, 32 GB inbuilt                          5000 mAh Battery
# 481     2 GB RAM, 32 GB inbuilt                          3020 mAh Battery
# 489   12 GB RAM, 512 GB inbuilt   5000 mAh Battery with 30W Fast Charging
# 550    8 GB RAM, 128 GB inbuilt   6000 mAh Battery with 44W Fast Charging
# 574     3 GB RAM, 16 GB inbuilt                          3360 mAh Battery
# 597     3 GB RAM, 32 GB inbuilt                          3000 mAh Battery
# 605   12 GB RAM, 128 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 649    8 GB RAM, 128 GB inbuilt   4400 mAh Battery with 66W Fast Charging
# 689     2 GB RAM, 32 GB inbuilt   5000 mAh Battery with 10W Fast Charging
# 690     2 GB RAM, 32 GB inbuilt   5000 mAh Battery with 18W Fast Charging
# 735     1 GB RAM, 16 GB inbuilt                          4000 mAh Battery
# 736    8 GB RAM, 256 GB inbuilt   4360 mAh Battery with 66W Fast Charging
# 738     2 GB RAM, 16 GB inbuilt                          3000 mAh Battery
# 744     1 GB RAM, 16 GB inbuilt                          4000 mAh Battery
# 794     1 GB RAM, 16 GB inbuilt                          4000 mAh Battery
# 800    8 GB RAM, 256 GB inbuilt   4200 mAh Battery with 40W Fast Charging
# 838     3 GB RAM, 32 GB inbuilt                          4800 mAh Battery
# 856     1 GB RAM, 16 GB inbuilt                          3000 mAh Battery
# 861     2 GB RAM, 32 GB inbuilt                          4030 mAh Battery
# 920    8 GB RAM, 128 GB inbuilt   4500 mAh Battery with 25W Fast Charging
# 923     2 GB RAM, 16 GB inbuilt                          4000 mAh Battery
# 983     3 GB RAM, 32 GB inbuilt                          4000 mAh Battery
# 990   12 GB RAM, 512 GB inbuilt       4500 mAh Battery with Fast Charging
# 992     2 GB RAM, 16 GB inbuilt                          4000 mAh Battery
# 996     3 GB RAM, 16 GB inbuilt                          2730 mAh Battery
# 1003    3 GB RAM, 32 GB inbuilt                          4000 mAh Battery
#
#                                                 display  \
# 14    6.8 inches, 1440 x 3088 px, 120 Hz Display wit...
# 49    6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 75    6.26 inches, 720 x 1600 px Display with Large ...
# 89    6.7 inches, 1080 x 2400 px, 120 Hz Display wit...
# 105   6.73 inches, 1440 x 3200 px, 120 Hz Display wi...
# 114   6.52 inches, 720 x 1600 px Display with Water ...
# 143                     5 inches, 720 x 1280 px Display
# 156   6.5 inches, 720 x 1600 px Display with Water D...
# 193   6.9 inches, 1400 x 3200 px, 120 Hz Display wit...
# 225   6.51 inches, 720 x 1600 px Display with Water ...
# 315   6.6 inches, 1600 x 720 px Display with Punch Hole
# 333   6.7 inches, 1080 x 2400 px, 120 Hz Display wit...
# 337   6.5 inches, 720 x 1600 px Display with Water D...
# 348   6.78 inches, 1260 x 2800 px, 120 Hz Display wi...
# 352                  5.45 inches, 720 x 1440 px Display
# 355   6.5 inches, 720 x 1600 px Display with Water D...
# 370          6.5 inches, 1644 x 3840 px, 120 Hz Display
# 403   6.52 inches, 720 x 1600 px Display with Water ...
# 404   6.71 inches, 1440 x 3214 px, 120 Hz Display wi...
# 407   6.78 inches, 1440 x 3200 px, 120 Hz Display wi...
# 447   6.6 inches, 720 x 1600 px Display with Water D...
# 462                 7.92 inches, 2088 x 2250 px Display
# 471   6.5 inches, 720 x 1600 px Display with Water D...
# 480   6.56 inches, 720 x 1600 px Display with Water ...
# 481                      5 inches, 854 x 480 px Display
# 489          6.5 inches, 1644 x 3840 px, 120 Hz Display
# 550   6.51 inches, 1080 x 2408 px, 144 Hz Display wi...
# 574                     6 inches, 720 x 1440 px Display
# 597                   5.5 inches, 720 x 1440 px Display
# 605   6.9 inches, 1440 x 3200 px Display with Punch ...
# 649   6.76 inches, 1344 x 2772 px, 90 Hz Display wit...
# 689   6.51 inches, 720 x 1600 px Display with Water ...
# 690   6.6 inches, 1612 x 720 px Display with Water D...
# 735   6.1 inches, 720 x 1520 px Display with Water D...
# 736   6.6 inches, 1288 x 2700 px, 120 Hz Display wit...
# 738                  5.45 inches, 720 x 1440 px Display
# 744   6.5 inches, 1600 x 720 px Display with Water D...
# 794                     6 inches, 720 x 1600 px Display
# 800   6.58 inches, 1200 x 2640 px, 90 Hz Display wit...
# 838   6.8 inches, 720 x 1600 px Display with Punch Hole
# 856                   5.3 inches, 720 x 1480 px Display
# 861   6.22 inches, 720 x 1520 px Display with Water ...
# 920   6.7 inches, 1440 x 3200 px Display with Punch ...
# 923   6.2 inches, 720 x 1520 px Display with Water D...
# 983   6.09 inches, 1520 x 720 px Display with Water ...
# 990   6.53 inches, 1176 x 2400 px Display with Large...
# 992   6.1 inches, 1560 x 720 px Display with Water D...
# 996                   5.2 inches, 720 x 1280 px Display
# 1003  6.5 inches, 1600 x 720 px Display with Water D...
#
#                                                  camera  \
# 14                200 MP Quad Rear & 12 MP Front Camera
# 49                108 MP Quad Rear & 32 MP Front Camera
# 75                  13 MP Dual Rear & 5 MP Front Camera
# 89                108 MP Quad Rear & 32 MP Front Camera
# 105   50.3 MP + 50 MP + 50 MP Triple Rear & 32 MP Fr...
# 114                  8 MP Dual Rear & 5 MP Front Camera
# 143                       5 MP Rear & 2 MP Front Camera
# 156                       8 MP Rear & 5 MP Front Camera
# 193              200 MP Penta Rear & 32 MP Front Camera
# 225                       8 MP Rear & 5 MP Front Camera
# 315   8 MP + 2 MP + 0.3 MP Triple Rear & 8 MP Front ...
# 333               108 MP Quad Rear & 32 MP Front Camera
# 337                       8 MP Rear & 5 MP Front Camera
# 348   50.3 MP + 50 MP + 12 MP Triple Rear & 32 MP Fr...
# 352                      13 MP Rear & 8 MP Front Camera
# 355                       8 MP Rear & 5 MP Front Camera
# 370   12 MP + 12 MP + 12 MP Triple Rear & 8 MP Front...
# 403                  8 MP Dual Rear & 5 MP Front Camera
# 404   200 MP + 12 MP + 12 MP Triple Rear & 10 MP Fro...
# 407                50 MP Quad Rear & 32 MP Front Camera
# 447                  8 MP Dual Rear & 5 MP Front Camera
# 462           108 MP + 20 MP + 12 MP Triple Rear Camera
# 471                       8 MP Rear & 5 MP Front Camera
# 480                  8 MP Dual Rear & 5 MP Front Camera
# 481                     2 MP Rear & 0.3 MP Front Camera
# 489                12 MP Quad Rear & 12 MP Front Camera
# 550               200 MP Quad Rear & 32 MP Front Camera
# 574                      13 MP Rear & 5 MP Front Camera
# 597                      13 MP Rear & 8 MP Front Camera
# 605               108 MP Quad Rear & 40 MP Front Camera
# 649   50 MP + 20 MP + 12 MP Triple Rear & 13 MP Dual...
# 689                       8 MP Rear & 5 MP Front Camera
# 690        8 MP + 0.08 MP Dual Rear & 5 MP Front Camera
# 735         5 MP + 0.3 MP Dual Rear & 5 MP Front Camera
# 736                50 MP Quad Rear & 13 MP Front Camera
# 738                       5 MP Rear & 5 MP Front Camera
# 744   8 MP + 2 MP + 0.3 MP Triple Rear & 8 MP Front ...
# 794                  8 MP Dual Rear & 5 MP Front Camera
# 800           50 MP Quad Rear & 32 MP Dual Front Camera
# 838                      13 MP Rear & 5 MP Front Camera
# 856                       8 MP Rear & 5 MP Front Camera
# 861                      13 MP Rear & 5 MP Front Camera
# 920                64 MP Quad Rear & 10 MP Front Camera
# 923          13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 983         8 MP + 0.3 MP Dual Rear & 5 MP Front Camera
# 990           40 MP Quad Rear & 32 MP Dual Front Camera
# 992          13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 996                      13 MP Rear & 5 MP Front Camera
# 1003                 8 MP Dual Rear & 5 MP Front Camera
#
#                                     card                               os
# 14             Memory Card Not Supported                      Android v13
# 49       Memory Card (Hybrid), upto 1 TB                      Android v12
# 75                 Memory Card Supported                     HarmonyOS v2
# 89       Memory Card (Hybrid), upto 1 TB                      Android v12
# 105            Memory Card Not Supported                      Android v13
# 114   Memory Card Supported, upto 512 GB                      Android v12
# 143   Memory Card Supported, upto 128 GB              Android v8.1 (Oreo)
# 156     Memory Card Supported, upto 1 TB                      Android v11
# 193                Memory Card Supported                    Android v12.1
# 225     Memory Card Supported, upto 1 TB                      Android v12
# 315    Memory Card Supported, upto 32 GB                      Android v10
# 333      Memory Card (Hybrid), upto 1 TB                      Android v12
# 337     Memory Card Supported, upto 1 TB                      Android v10
# 348            Memory Card Not Supported                      Android v13
# 352   Memory Card Supported, upto 512 GB                      Android v11
# 355     Memory Card Supported, upto 1 TB                      Android v12
# 370      Memory Card (Hybrid), upto 1 TB                      Android v11
# 403   Memory Card Supported, upto 512 GB                      Android v12
# 404      Memory Card (Hybrid), upto 1 TB                      Android v12
# 407            Memory Card Not Supported                      Android v12
# 447   Memory Card Supported, upto 512 GB                      Android v11
# 462            Memory Card Not Supported                      Android v10
# 471   Memory Card Supported, upto 256 GB                      Android v11
# 480     Memory Card Supported, upto 1 TB                      Android v12
# 481                Memory Card Supported                      Android v12
# 489                 Memory Card (Hybrid)                      Android v12
# 550                Memory Card Supported                      Android v11
# 574                Memory Card Supported              Android v8.1 (Oreo)
# 597                Memory Card Supported  Pragati OS (Powered by Android)
# 605      Memory Card (Hybrid), upto 1 TB                    Android v10.0
# 649    Memory Card (Hybrid), upto 256 GB                     Harmony v2.0
# 689     Memory Card Supported, upto 1 TB                      Android v12
# 690   Memory Card Supported, upto 128 GB                    Android v11.0
# 735                Memory Card Supported                      Android v11
# 736    Memory Card (Hybrid), upto 256 GB                   HarmonyOS v2.0
# 738   Memory Card Supported, upto 256 GB                      Android v11
# 744    Memory Card Supported, upto 32 GB                      Android v10
# 794    Memory Card Supported, upto 32 GB               Android v9.0 (Pie)
# 800    Memory Card (Hybrid), upto 256 GB                    Android v10.0
# 838                Memory Card Supported                      Android v10
# 856                Memory Card Supported                      Android v10
# 861   Memory Card Supported, upto 256 GB              Android v8.1 (Oreo)
# 920      Memory Card (Hybrid), upto 1 TB                      Android v10
# 923   Memory Card Supported, upto 256 GB              Android v8.1 (Oreo)
# 983   Memory Card Supported, upto 128 GB                 Android v9 (Pie)
# 990    Memory Card (Hybrid), upto 256 GB                      Android v10
# 992   Memory Card Supported, upto 256 GB               Android v9.0 (Pie)
# 996                Memory Card Supported       Android v6.0 (Marshmallow)
# 1003   Memory Card (Hybrid), upto 512 GB                      Android v12

# %% [markdown]
# ### Sim

# %%
final_df["sim"]
# Out:
# 0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#                               ...
# 1010                       Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1016                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# Name: sim, Length: 725, dtype: object

# %%
final_df.shape
# Out:
# (725, 11)

# %%
# 4G phones in the data

(
    final_df["sim"]
    .str.contains("4G")
    .sum()
)
# Out:
# np.int64(724)

# %%
# phone that is non 4G

(
    final_df["sim"]
    .str.contains("4G")
    .loc[lambda x: x == False]
)
# Out:
# 735    False
# Name: sim, dtype: bool

# %%
final_df.loc[735]
# Out:
# model                                           Tecno Pop 5 Go
# price                                                   ₹6,999
# rating                                                     NaN
# sim                                        Dual Sim, 3G, Wi-Fi
# processor     Spreadtrum  SC7731, Quad Core, 1.3 GHz Processor
# ram                                    1 GB RAM, 16 GB inbuilt
# battery                                       4000 mAh Battery
# display      6.1 inches, 720 x 1520 px Display with Water D...
# camera             5 MP + 0.3 MP Dual Rear & 5 MP Front Camera
# card                                     Memory Card Supported
# os                                                 Android v11
# Name: 735, dtype: object

# %%
# number of sims

(
final_df["sim"]
.str.extract("(\w+) Sim",flags=re.IGNORECASE)
.value_counts()
)
# Out:
# 0
# Dual      718
# Single      7
# Name: count, dtype: int64

# %%
(
    final_df["sim"]
    .str.extract("(\w+) Sim",flags=re.IGNORECASE)
    .squeeze()
    .loc[lambda ser: ser == "Single"]
    .index
)
# Out:
# Index([174, 429, 431, 457, 506, 870, 899], dtype='int64')

# %%
final_df.loc[[174, 429, 431, 457, 506, 870, 899]]
# Out:
#                           model      price  rating  \
# 174              Apple iPhone 9    ₹29,990    61.0
# 429                Nokia X50 5G    ₹34,999    76.0
# 431       Vertu Signature Touch  ₹6,50,000    62.0
# 457           Sony Xperia L5 5G    ₹15,990    73.0
# 506           Google Pixel 2 XL    ₹15,990    69.0
# 870       Samsung Galaxy S10 5G    ₹78,990    86.0
# 899  Sony Xperia 10 III Lite 5G    ₹30,990    78.0
#
#                                            sim  \
# 174      Single Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 429       Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 431             Single Sim, 3G, 4G, Wi-Fi, NFC
# 457      Single Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 506      Single Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 870  Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 899  Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                          processor                       ram  \
# 174      A13 Bionic, Hexa Core, 2.65 GHz Processor   3 GB RAM, 64 GB inbuilt
# 429                                 Snapdragon 775   6 GB RAM, 64 GB inbuilt
# 431   Snapdragon 801, Octa Core, 1.5 GHz Processor   2 GB RAM, 64 GB inbuilt
# 457       Helio  P35, Octa Core, 2.3 GHz Processor   4 GB RAM, 64 GB inbuilt
# 506  Snapdragon 835, Octa Core, 2.35 GHz Processor  4 GB RAM, 128 GB inbuilt
# 870      Exynos 9820, Octa Core, 2.7 GHz Processor  8 GB RAM, 256 GB inbuilt
# 899   Snapdragon  690 , Octa Core, 2 GHz Processor   6 GB RAM, 64 GB inbuilt
#
#                                      battery  \
# 174      2050 mAh Battery with Fast Charging
# 429  6000 mAh Battery with 33W Fast Charging
# 431                         2275 mAh Battery
# 457      4000 mAh Battery with Fast Charging
# 506      3520 mAh Battery with Fast Charging
# 870  4500 mAh Battery with 25W Fast Charging
# 899  4500 mAh Battery with 30W Fast Charging
#
#                                                display  \
# 174  4.7 inches, 750 x 1334 px Display with Large N...
# 429  6.81 inches, 1080 x 2400 px Display with Punch...
# 431                 4.7 inches, 1080 x 1920 px Display
# 457                  6.2 inches, 720 x 1680 px Display
# 506                   6 inches, 1440 x 2880 px Display
# 870                 6.7 inches, 1440 x 3040 px Display
# 899                   6 inches, 1080 x 2520 px Display
#
#                                                 camera  \
# 174                     12 MP Rear & 7 MP Front Camera
# 429              108 MP Quad Rear & 32 MP Front Camera
# 431                   13 MP Rear & 2.1 MP Front Camera
# 457  13 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...
# 506                   12.2 MP Rear & 8 MP Front Camera
# 870  16 MP + 12 MP + 12 MP Triple Rear & 10 MP Fron...
# 899  12 MP + 8 MP + 8 MP Triple Rear & 8 MP Front C...
#
#                                   card                       os
# 174          Memory Card Not Supported                iOS v13.0
# 429              Memory Card Supported              Android v11
# 431          Memory Card Not Supported  Android v4.4.2 (KitKat)
# 457  Memory Card (Hybrid), upto 512 GB              Android v12
# 506          Memory Card Not Supported      Android v8.0 (Oreo)
# 870  Memory Card (Hybrid), upto 512 GB       Android v9.0 (Pie)
# 899              Memory Card Supported              Android v11

# %%
def clean_sim(ser: pd.Series) -> pd.DataFrame:
    result_df = pd.DataFrame()

    return (
        result_df
        .assign(
            number_of_sim=ser.str.extract("(\w+) Sim",flags=re.IGNORECASE),
            has_5G=ser.str.contains("5G", flags=re.IGNORECASE),
            has_NFC=ser.str.contains("NFC", flags=re.IGNORECASE),
            has_IR_Blaster=ser.str.contains("IR Blaster", flags=re.IGNORECASE)
        )
        .assign(
            number_of_sim=lambda df_: np.where(df_["number_of_sim"] == "Dual", 2, 1)
        )
    )

# %%
clean_sim(final_df["sim"]).shape
# Out:
# (725, 4)

# %%
clean_sim(final_df["sim"]).isna().sum()
# Out:
# number_of_sim     0
# has_5G            0
# has_NFC           0
# has_IR_Blaster    0
# dtype: int64

# %% [markdown]
# ### Processor

# %%
(
    final_df["processor"]
)
# Out:
# 0       Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1          Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2             Exynos 1330, Octa Core, 2.4 GHz Processor
# 3         Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4          Dimensity 1080, Octa Core, 2.6 GHz Processor
#                              ...
# 1010          Tiger T612, Octa Core, 1.82 GHz Processor
# 1016     Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017      Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018       Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                                Octa Core Processor
# Name: processor, Length: 725, dtype: object

# %%
def clean_processor(ser: pd.Series):
    temp_df = pd.DataFrame()

    return (
        temp_df
        .assign(
            cpu_speed=ser.str.extract("(\d+\.?\d*).?GHz").astype(np.float64),
            number_of_cores=ser.str.extract("(\w+)\sCore"),
            processor_name=np.where(ser.str.count(",").eq(2), ser.str.split(",", n=1).str.get(0), np.nan)
        )
        .assign(
            number_of_cores= lambda df_: np.select(condlist=[df_["number_of_cores"].str.contains("Octa", case=False, na=False),
                                                            df_["number_of_cores"].str.contains("Hexa", case=False, na=False),
                                                            df_["number_of_cores"].str.contains("Quad", case=False, na=False),
                                                            df_["number_of_cores"].str.contains("Dual", case=False, na=False)],
                                                            choicelist=[8, 6, 4, 2],
                                                            default=1),
            processor_name=lambda df_: df_["processor_name"].str.split(" ", n=1).str.get(0)
        )
    )

# %%
clean_processor(final_df["processor"]).join(final_df["processor"])
# Out:
#       cpu_speed  number_of_cores processor_name  \
# 0          3.20                8     Snapdragon
# 1          2.20                8     Snapdragon
# 2          2.40                8         Exynos
# 3          2.20                8     Snapdragon
# 4          2.60                8      Dimensity
# ...         ...              ...            ...
# 1010       1.82                8          Tiger
# 1016       2.20                8     Snapdragon
# 1017       2.85                8      Dimensity
# 1018       2.20                8     Snapdragon
# 1019        NaN                8            NaN
#
#                                             processor
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1010        Tiger T612, Octa Core, 1.82 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
# [725 rows x 4 columns]

# %%
clean_processor(final_df["processor"]).isna().sum()
# Out:
# cpu_speed          36
# number_of_cores     0
# processor_name     47
# dtype: int64

# %%
clean_processor(final_df["processor"]).dtypes
# Out:
# cpu_speed          float64
# number_of_cores      int64
# processor_name      object
# dtype: object

# %%
(
    clean_processor(final_df["processor"])
    .loc[clean_processor(final_df["processor"]).isna().any(axis=1),:]
    .join(final_df["processor"])
)
# Out:
#       cpu_speed  number_of_cores processor_name  \
# 27          NaN                6            NaN
# 78          NaN                8            NaN
# 100         NaN                6            NaN
# 118         NaN                8            NaN
# 122         NaN                8            NaN
# 129         NaN                8            NaN
# 143         1.4                4            NaN
# 152         NaN                1            NaN
# 188         1.6                4            NaN
# 201         2.0                8            NaN
# 207         NaN                8            NaN
# 210         NaN                6            NaN
# 225         NaN                8            NaN
# 242         NaN                8            NaN
# 256         NaN                8            NaN
# 263         NaN                1            NaN
# 282         NaN                1            NaN
# 290         NaN                6            NaN
# 309         2.0                8            NaN
# 315         1.3                4            NaN
# 364         NaN                8            NaN
# 402         NaN                8            NaN
# 420         NaN                6            NaN
# 429         NaN                1            NaN
# 496         NaN                8            NaN
# 529         NaN                8            NaN
# 587         2.0                8            NaN
# 689         NaN                8            NaN
# 728         NaN                1            NaN
# 758         1.6                4            NaN
# 764         NaN                6            NaN
# 778         2.2                8            NaN
# 794         1.3                4            NaN
# 814         NaN                6            NaN
# 825         NaN                8            NaN
# 826         NaN                8            NaN
# 828         NaN                8            NaN
# 830         NaN                8            NaN
# 831         NaN                8            NaN
# 875         NaN                8            NaN
# 876         NaN                8            NaN
# 928         NaN                6            NaN
# 948         NaN                8            NaN
# 949         NaN                8            NaN
# 991         1.8                8            NaN
# 1005        1.3                4            NaN
# 1019        NaN                8            NaN
#
#                                      processor
# 27            Bionic  A16, Hexa Core Processor
# 78            Exynos 1280, Octa Core Processor
# 100           Bionic  A16, Hexa Core Processor
# 118                        Octa Core Processor
# 122        Google  Tensor, Octa Core Processor
# 129        Google  Tensor, Octa Core Processor
# 143               Quad Core, 1.4 GHz Processor
# 152                                Bionic  A16
# 188               Quad Core, 1.6 GHz Processor
# 201                 Octa Core, 2 GHz Processor
# 207           Exynos 1380, Octa Core Processor
# 210           Bionic  A16, Hexa Core Processor
# 225                 Helio, Octa Core Processor
# 242      Snapdragon 778G+, Octa Core Processor
# 256          Exynos  2300, Octa Core Processor
# 263                                 Apple  A13
# 282                                 Bionic A16
# 290           Bionic  A16, Hexa Core Processor
# 309                 Octa Core, 2 GHz Processor
# 315               Quad Core, 1.3 GHz Processor
# 364   Snapdragon 8+ Gen 2, Octa Core Processor
# 402           Bionic  A17, Octa Core Processor
# 420           Bionic  A16, Hexa Core Processor
# 429                             Snapdragon 775
# 496                        Octa Core Processor
# 529                        Octa Core Processor
# 587                 Octa Core, 2 GHz Processor
# 689                 Helio, Octa Core Processor
# 728                                Bionic  A16
# 758               Quad Core, 1.6 GHz Processor
# 764           Bionic  A16, Hexa Core Processor
# 778               Octa Core, 2.2 GHz Processor
# 794               Quad Core, 1.3 GHz Processor
# 814           Bionic  A16, Hexa Core Processor
# 825                        Octa Core Processor
# 826                        Octa Core Processor
# 828      Snapdragon 778G+, Octa Core Processor
# 830           Exynos 1330, Octa Core Processor
# 831     Snapdragon  778G+, Octa Core Processor
# 875                        Octa Core Processor
# 876    Snapdragon  7 Gen2, Octa Core Processor
# 928            Bionic A16, Hexa Core Processor
# 948                        Octa Core Processor
# 949                        Octa Core Processor
# 991               Octa Core, 1.8 GHz Processor
# 1005              Quad Core, 1.3 GHz Processor
# 1019                       Octa Core Processor

# %% [markdown]
# ### Ram

# %%
final_df["ram"]
# Out:
# 0       12 GB RAM, 256 GB inbuilt
# 1        6 GB RAM, 128 GB inbuilt
# 2         4 GB RAM, 64 GB inbuilt
# 3        6 GB RAM, 128 GB inbuilt
# 4        6 GB RAM, 128 GB inbuilt
#                   ...
# 1010      4 GB RAM, 64 GB inbuilt
# 1016     6 GB RAM, 128 GB inbuilt
# 1017     8 GB RAM, 256 GB inbuilt
# 1018     6 GB RAM, 128 GB inbuilt
# 1019     8 GB RAM, 128 GB inbuilt
# Name: ram, Length: 725, dtype: object

# %%
(
    final_df["ram"]
    .str.findall("(\d+).?(?:GB|TB)")
    .to_frame()
    .rename(columns={"ram": "memory"})
    .assign(
        ram= lambda df_: df_["memory"].str.get(0),
        storage=lambda df_: df_["memory"].str.get(1)
    )
)
# Out:
#          memory ram storage
# 0     [12, 256]  12     256
# 1      [6, 128]   6     128
# 2       [4, 64]   4      64
# 3      [6, 128]   6     128
# 4      [6, 128]   6     128
# ...         ...  ..     ...
# 1010    [4, 64]   4      64
# 1016   [6, 128]   6     128
# 1017   [8, 256]   8     256
# 1018   [6, 128]   6     128
# 1019   [8, 128]   8     128
#
# [725 rows x 3 columns]

# %%
final_df["ram"]
# Out:
# 0       12 GB RAM, 256 GB inbuilt
# 1        6 GB RAM, 128 GB inbuilt
# 2         4 GB RAM, 64 GB inbuilt
# 3        6 GB RAM, 128 GB inbuilt
# 4        6 GB RAM, 128 GB inbuilt
#                   ...
# 1010      4 GB RAM, 64 GB inbuilt
# 1016     6 GB RAM, 128 GB inbuilt
# 1017     8 GB RAM, 256 GB inbuilt
# 1018     6 GB RAM, 128 GB inbuilt
# 1019     8 GB RAM, 128 GB inbuilt
# Name: ram, Length: 725, dtype: object

# %%
def clean_ram(ser: pd.Series):
    temp_df = pd.DataFrame()
    return (
        temp_df
        .assign(
            memory= lambda df_: (ser.
                                 str.extract("(\d+).?(?:GB|TB)\sRAM", flags=re.IGNORECASE)
                                 .astype(np.float64)),
            storage=lambda df_: (ser
                                 .str.extract("(\d+).?(?:GB|TB)\sinbuilt", flags=re.IGNORECASE)
                                 .astype(np.float64))
                                 .replace(1.0, 1024.0)
        )

    )

# %%
clean_ram(final_df["ram"])
# Out:
#       memory  storage
# 0       12.0    256.0
# 1        6.0    128.0
# 2        4.0     64.0
# 3        6.0    128.0
# 4        6.0    128.0
# ...      ...      ...
# 1010     4.0     64.0
# 1016     6.0    128.0
# 1017     8.0    256.0
# 1018     6.0    128.0
# 1019     8.0    128.0
#
# [725 rows x 2 columns]

# %%
clean_ram(final_df["ram"]).isna().sum()
# Out:
# memory     1
# storage    0
# dtype: int64

# %%
clean_ram(final_df["ram"])["storage"].unique()
# Out:
# array([ 256.,  128.,   64.,   32.,  512., 1024.,   16.])

# %%
clean_ram(final_df["ram"])["memory"].unique()
# Out:
# array([12.,  6.,  4.,  8.,  3.,  2., 16., 18., nan,  1.])

# %%
final_df.loc[clean_ram(final_df["ram"])["storage"] == 1024]
# Out:
#                              model      price  rating  \
# 290  Apple iPhone 14 Pro Max (1TB)  ₹1,82,999    78.0
# 781  Apple iPhone 13 Pro Max (1TB)  ₹1,79,900    86.0
# 814      Apple iPhone 14 Pro (1TB)  ₹1,72,999    77.0
# 961      Apple iPhone 13 Pro (1TB)  ₹1,47,900    84.0
#
#                                          sim  \
# 290  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 781  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 814  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 961  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                      processor                     ram  \
# 290           Bionic  A16, Hexa Core Processor  6 GB RAM, 1 TB inbuilt
# 781  Bionic A15, Hexa Core, 3.22 GHz Processor  6 GB RAM, 1 TB inbuilt
# 814           Bionic  A16, Hexa Core Processor  6 GB RAM, 1 TB inbuilt
# 961  Bionic A15, Hexa Core, 3.22 GHz Processor  6 GB RAM, 1 TB inbuilt
#
#                                  battery  \
# 290  4323 mAh Battery with Fast Charging
# 781  4352 mAh Battery with Fast Charging
# 814  3200 mAh Battery with Fast Charging
# 961  3095 mAh Battery with Fast Charging
#
#                                                display  \
# 290         6.7 inches, 1290 x 2796 px, 120 Hz Display
# 781  6.7 inches, 1284 x 2778 px, 120 Hz Display wit...
# 814         6.1 inches, 1179 x 2556 px, 120 Hz Display
# 961  6.1 inches, 1170 x 2532 px, 120 Hz Display wit...
#
#                                                 camera  \
# 290  48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 781  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 814  48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 961  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
#
#                           card         os
# 290  Memory Card Not Supported    iOS v16
# 781  Memory Card Not Supported    iOS v15
# 814  Memory Card Not Supported    iOS v16
# 961  Memory Card Not Supported  iOS v15.0

# %%
final_df.loc[(
    clean_ram(final_df["ram"])
    .isna()
    .any(axis=1)
    )]
# Out:
#                                 model      price  rating  \
# 483  Huawei Mate 50 RS Porsche Design  ₹2,39,999    81.0
#
#                                                  sim  \
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
#
#                                             processor             ram  \
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
#
#                                      battery  \
# 483  4700 mAh Battery with 66W Fast Charging
#
#                                          display  \
# 483  6.74 inches, 1212 x 2616 px, 120 Hz Display
#
#                                                 camera  \
# 483  50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
#
#                                   card                os
# 483  Memory Card (Hybrid), upto 256 GB  Hongmeng OS v3.0

# %%
df.columns
# Out:
# Index(['model', 'price', 'rating', 'sim', 'processor', 'ram', 'battery',
#        'display', 'camera', 'card', 'os'],
#       dtype='object')

# %% [markdown]
# ### Battery

# %%
def clean_battery(ser: pd.Series):
    temp_df = pd.DataFrame()

    return(
        temp_df
        .assign(
            capacity=ser.str.extract("(\d+).?mAh"),
            fast_charging=ser.str.contains("Fast Charging", flags=re.IGNORECASE),
            fast_charging_power=ser.str.extract("(\d+)\s?W")
        )

    )

# %%
clean_battery(final_df["battery"]).join(final_df["battery"])
# Out:
#      capacity  fast_charging fast_charging_power  \
# 0        5000           True                 100
# 1        5000           True                  33
# 2        5000           True                  15
# 3        5000           True                 NaN
# 4        5000           True                  67
# ...       ...            ...                 ...
# 1010     5000           True                  10
# 1016     5000           True                   5
# 1017     5080           True                  67
# 1018     5000           True                 NaN
# 1019     5000           True                 NaN
#
#                                         battery
# 0      5000 mAh Battery with 100W Fast Charging
# 1       5000 mAh Battery with 33W Fast Charging
# 2       5000 mAh Battery with 15W Fast Charging
# 3           5000 mAh Battery with Fast Charging
# 4       5000 mAh Battery with 67W Fast Charging
# ...                                         ...
# 1010    5000 mAh Battery with 10W Fast Charging
# 1016  5000 mAh Battery with 22.5W Fast Charging
# 1017    5080 mAh Battery with 67W Fast Charging
# 1018        5000 mAh Battery with Fast Charging
# 1019        5000 mAh Battery with Fast Charging
#
# [725 rows x 4 columns]

# %%
clean_battery(final_df["battery"]).isna().sum()
# Out:
# capacity                 0
# fast_charging            0
# fast_charging_power    181
# dtype: int64

# %%
final_df.loc[clean_battery(final_df["battery"])["fast_charging_power"].isna(),["battery"]].join(clean_battery(final_df["battery"]))
# Out:
#                                   battery capacity  fast_charging  \
# 3     5000 mAh Battery with Fast Charging     5000           True
# 6     3279 mAh Battery with Fast Charging     3279           True
# 15    3240 mAh Battery with Fast Charging     3240           True
# 25    4500 mAh Battery with Fast Charging     4500           True
# 27    4323 mAh Battery with Fast Charging     4323           True
# ...                                   ...      ...            ...
# 1003                     4000 mAh Battery     4000          False
# 1005                     5000 mAh Battery     5000          False
# 1006                     8000 mAh Battery     8000          False
# 1018  5000 mAh Battery with Fast Charging     5000           True
# 1019  5000 mAh Battery with Fast Charging     5000           True
#
#      fast_charging_power
# 3                    NaN
# 6                    NaN
# 15                   NaN
# 25                   NaN
# 27                   NaN
# ...                  ...
# 1003                 NaN
# 1005                 NaN
# 1006                 NaN
# 1018                 NaN
# 1019                 NaN
#
# [181 rows x 4 columns]

# %%
(
    final_df["battery"]
)
# Out:
# 0        5000 mAh Battery with 100W Fast Charging
# 1         5000 mAh Battery with 33W Fast Charging
# 2         5000 mAh Battery with 15W Fast Charging
# 3             5000 mAh Battery with Fast Charging
# 4         5000 mAh Battery with 67W Fast Charging
#                           ...
# 1010      5000 mAh Battery with 10W Fast Charging
# 1016    5000 mAh Battery with 22.5W Fast Charging
# 1017      5080 mAh Battery with 67W Fast Charging
# 1018          5000 mAh Battery with Fast Charging
# 1019          5000 mAh Battery with Fast Charging
# Name: battery, Length: 725, dtype: object

# %% [markdown]
# ### Display

# %%
df.columns
# Out:
# Index(['model', 'price', 'rating', 'sim', 'processor', 'ram', 'battery',
#        'display', 'camera', 'card', 'os'],
#       dtype='object')

# %%
final_df["display"]
# Out:
# 0       6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1       6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2       6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3       6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4       6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#                               ...
# 1010    6.5 inches, 720 x 1600 px Display with Water D...
# 1016    6.5 inches, 720 x 1600 px Display with Water D...
# 1017    6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018    6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019    6.5 inches, 1080 x 2400 px Display with Water ...
# Name: display, Length: 725, dtype: object

# %%
def clean_display(ser: pd.Series):
    temp_df = pd.DataFrame()
    return (
        temp_df
        .assign(
            display_size= ser.str.extract("(\d+\.?\d*)\sinches").astype(np.float64),
            resolution= ser.str.extract("(\d+.?x.?\d+).?(?:px)?"),
            refresh_rate= ser.str.extract("(\d+)\sHz")
        )
    )

# %%
clean_display(final_df["display"]).join(final_df["display"])
# Out:
#       display_size   resolution refresh_rate  \
# 0             6.70  1440 x 3216          120
# 1             6.59  1080 x 2412          120
# 2             6.60  1080 x 2408           90
# 3             6.55  1080 x 2400          120
# 4             6.70  1080 x 2412          120
# ...            ...          ...          ...
# 1010          6.50   720 x 1600          NaN
# 1016          6.50   720 x 1600          NaN
# 1017          6.60  1080 x 2460          144
# 1018          6.80  1080 x 2400          NaN
# 1019          6.50  1080 x 2400          NaN
#
#                                                 display
# 0     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1010  6.5 inches, 720 x 1600 px Display with Water D...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
# [725 rows x 4 columns]

# %%
clean_display(final_df["display"]).isna().sum()
# Out:
# display_size      0
# resolution        0
# refresh_rate    327
# dtype: int64

# %%
df.columns
# Out:
# Index(['model', 'price', 'rating', 'sim', 'processor', 'ram', 'battery',
#        'display', 'camera', 'card', 'os'],
#       dtype='object')

# %% [markdown]
# ### Camera

# %%
final_df["camera"]
# Out:
# 0       50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1       64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2       50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3       50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4       108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#                               ...
# 1010                        8 MP Rear & 5 MP Front Camera
# 1016    48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017    64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018    108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019    64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
# Name: camera, Length: 725, dtype: object

# %%
(
    final_df["camera"]
    .str.replace("\u2009","")
    .str.strip()
    .str.extract("(\d+)MP.* (\w+) Rear.* (\d+)MP Front")
    .rename(columns={k:v for k,v in enumerate(["rear_camera", "num_of_cameras", "front_camera"])})
)
# Out:
#      rear_camera num_of_cameras front_camera
# 0             50         Triple           16
# 1             64         Triple           16
# 2             50         Triple           13
# 3             50         Triple           16
# 4            108         Triple           16
# ...          ...            ...          ...
# 1010         NaN            NaN          NaN
# 1016          48         Triple            8
# 1017          64         Triple           16
# 1018         108         Triple           32
# 1019          64         Triple           32
#
# [725 rows x 3 columns]

# %%
def clean_camera(ser: pd.Series):
    temp_df = pd.DataFrame()

    return(
            temp_df
            .assign(
                rear_camera= ser.str.extract("(\d+).?MP").astype(np.float64),
                front_camera=ser.str.extract("(\d+).?MP\sFront").astype(np.float64),
                num_of_cameras=ser.str.extract("(\w{4,6})\sRear"),
            )
    )

# %%
clean_camera(final_df["camera"]).join(final_df["camera"])
# Out:
#       rear_camera  front_camera num_of_cameras  \
# 0            50.0          16.0         Triple
# 1            64.0          16.0         Triple
# 2            50.0          13.0         Triple
# 3            50.0          16.0         Triple
# 4           108.0          16.0         Triple
# ...           ...           ...            ...
# 1010          8.0           5.0            NaN
# 1016         48.0           8.0         Triple
# 1017         64.0          16.0         Triple
# 1018        108.0          32.0         Triple
# 1019         64.0          32.0         Triple
#
#                                                  camera
# 0     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ...                                                 ...
# 1010                      8 MP Rear & 5 MP Front Camera
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
# [725 rows x 4 columns]

# %%
clean_camera(final_df["camera"]).isna().sum()
# Out:
# rear_camera        0
# front_camera      17
# num_of_cameras    53
# dtype: int64

# %%
clean_camera(final_df["camera"]).loc[clean_camera(final_df["camera"]).isna().any(axis=1)].join(final_df["camera"])
# Out:
#       rear_camera  front_camera num_of_cameras  \
# 52           13.0           8.0            NaN
# 70            8.0           5.0            NaN
# 71           64.0           NaN         Triple
# 79           13.0           5.0            NaN
# 125          64.0           NaN         Triple
# ...           ...           ...            ...
# 979          13.0           5.0            NaN
# 990          40.0           NaN           Quad
# 996          13.0           5.0            NaN
# 1005         20.0          13.0            NaN
# 1010          8.0           5.0            NaN
#
#                                                  camera
# 52                       13 MP Rear & 8 MP Front Camera
# 70                        8 MP Rear & 5 MP Front Camera
# 71    64 MP + 8 MP + 2 MP Triple Rear & 50 MP + 8 MP...
# 79                       13 MP Rear & 5 MP Front Camera
# 125   64 MP + 8 MP + 2 MP Triple Rear & 50 MP + 8 MP...
# ...                                                 ...
# 979                      13 MP Rear & 5 MP Front Camera
# 990           40 MP Quad Rear & 32 MP Dual Front Camera
# 996                      13 MP Rear & 5 MP Front Camera
# 1005                    20 MP Rear & 13 MP Front Camera
# 1010                      8 MP Rear & 5 MP Front Camera
#
# [70 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['model', 'price', 'rating', 'sim', 'processor', 'ram', 'battery',
#        'display', 'camera', 'card', 'os'],
#       dtype='object')

# %% [markdown]
# ### Card

# %%
(
    final_df["card"].sample(20)
)
# Out:
# 352     Memory Card Supported, upto 512 GB
# 179        Memory Card (Hybrid), upto 1 TB
# 435                  Memory Card Supported
# 76               Memory Card Not Supported
# 901     Memory Card Supported, upto 256 GB
# 387              Memory Card Not Supported
# 438     Memory Card Supported, upto 512 GB
# 36        Memory Card Supported, upto 1 TB
# 571     Memory Card Supported, upto 512 GB
# 214       Memory Card Supported, upto 1 TB
# 711     Memory Card Supported, upto 256 GB
# 103       Memory Card Supported, upto 1 TB
# 900     Memory Card Supported, upto 256 GB
# 877                  Memory Card Supported
# 1          Memory Card (Hybrid), upto 1 TB
# 1019      Memory Card Supported, upto 1 TB
# 937                  Memory Card Supported
# 283       Memory Card Supported, upto 1 TB
# 82        Memory Card Supported, upto 1 TB
# 870      Memory Card (Hybrid), upto 512 GB
# Name: card, dtype: object

# %%
def clean_card(ser: pd.Series):
    temp_df = pd.DataFrame()

    return (
        temp_df
        .assign(
            card_size=lambda df_: ser.str.extract("(\d+).?(?:TB|GB)").astype(np.float64).replace(1.0, 1024.0),
            has_card=lambda df_: np.where(df_["card_size"].notna(), True, False)
        )
    )

# %%
clean_card(final_df["card"])
# Out:
#       card_size  has_card
# 0           NaN     False
# 1        1024.0      True
# 2        1024.0      True
# 3        1024.0      True
# 4           NaN     False
# ...         ...       ...
# 1010     1024.0      True
# 1016     1024.0      True
# 1017        NaN     False
# 1018     1024.0      True
# 1019     1024.0      True
#
# [725 rows x 2 columns]

# %% [markdown]
# ### Os

# %%
final_df["os"].unique()
# Out:
# array(['Android v13', 'Android v12', 'iOS v16', 'iOS v15', 'Android v11',
#        'Android v10', 'iOS v13', 'HarmonyOS v2', 'iOS v15.0',
#        'Android v10.0', 'Android v8.1 (Oreo)', 'iOS v13.0',
#        'Android v11.0', 'Android v12.1', 'iOS v12.3',
#        'Android v9.0 (Pie)', 'iOS v17', 'Android v4.4.2 (KitKat)',
#        'Hongmeng OS v3.0', 'Android v8.0 (Oreo)',
#        'Pragati OS (Powered by Android)', 'Harmony v2.0',
#        'Hongmeng OS v4.0', 'HarmonyOS v2.0', 'Android v6.0 (Marshmallow)',
#        'EMUI v12', 'Android v7.1 (Nougat)', 'Android', 'Android v9 (Pie)'],
#       dtype=object)

# %% [markdown]
# ## Semi Final step

# %%
df.columns
# Out:
# Index(['model', 'price', 'rating', 'sim', 'processor', 'ram', 'battery',
#        'display', 'camera', 'card', 'os'],
#       dtype='object')

# %%
final_df.columns[3:10].to_list() + ["model"]
# Out:
# ['sim', 'processor', 'ram', 'battery', 'display', 'camera', 'card', 'model']

# %%
def clean_phone_data(data: pd.DataFrame):
    return(
        data
        .join(data["model"].pipe(clean_model))      # cleaning model columnn --> brand, model_name
        .join(data["sim"].pipe(clean_sim))
        .join(data["processor"].pipe(clean_processor))
        .join(data["ram"].pipe(clean_ram))
        .join(data["battery"].pipe(clean_battery))
        .join(data["display"].pipe(clean_display))
        .join(data["camera"].pipe(clean_camera))
        .join(data["card"].pipe(clean_card))
        .drop(columns=["model"] + data.columns[3:10].to_list() + ["os"])
        .assign(
            price=lambda df_ : df_["price"].pipe(clean_price)
        )
    )

# %%
final_df.sample(10)
# Out:
#                                           model    price  rating  \
# 663                          Infinix Hot 12 Pro  ₹10,850    74.0
# 101             Xiaomi Redmi Note 11 Pro Max 5G  ₹19,999    83.0
# 292            Poco M4 Pro 5G (8GB RAM + 128GB)  ₹15,999    82.0
# 695                         Infinix Note 13 Pro  ₹16,999    80.0
# 245  Xiaomi Redmi Note 11T 5G (6GB RAM + 128GB)  ₹16,999    81.0
# 771                                   Vivo Y15C   ₹8,499    66.0
# 798                     Samsung Galaxy S20 Plus  ₹83,000    88.0
# 199                          Samsung Galaxy M04   ₹8,499    66.0
# 325                               Tecno Spark 9   ₹8,999    69.0
# 174                              Apple iPhone 9  ₹29,990    61.0
#
#                                                 sim  \
# 663                  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 101  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 292  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 695                  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 245  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 771                  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 798             Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 199                  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 325                  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 174           Single Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
#
#                                            processor  \
# 663           Tiger T616, Octa Core, 2 GHz Processor
# 101    Snapdragon 778G, Octa Core, 2.4 GHz Processor
# 292  Dimensity  810 5G, Octa Core, 2.4 GHz Processor
# 695         Helio  G99, Octa Core, 2.2 GHz Processor
# 245  Dimensity  810 5G, Octa Core, 2.4 GHz Processor
# 771          Helio P35, Octa Core, 2.3 GHz Processor
# 798        Exynos 990, Octa Core, 2.73 GHz Processor
# 199          Helio P35, Octa Core, 2.3 GHz Processor
# 325          Helio G37, Octa Core, 2.3 GHz Processor
# 174        A13 Bionic, Hexa Core, 2.65 GHz Processor
#
#                           ram                                   battery  \
# 663   6 GB RAM, 64 GB inbuilt   5000 mAh Battery with 18W Fast Charging
# 101  6 GB RAM, 128 GB inbuilt   5200 mAh Battery with 33W Fast Charging
# 292  8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 695  6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 120W Fast Charging
# 245  6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 771   3 GB RAM, 32 GB inbuilt                          5000 mAh Battery
# 798  8 GB RAM, 128 GB inbuilt   4500 mAh Battery with 25W Fast Charging
# 199   4 GB RAM, 64 GB inbuilt   5000 mAh Battery with 15W Fast Charging
# 325  6 GB RAM, 128 GB inbuilt                          5000 mAh Battery
# 174   3 GB RAM, 64 GB inbuilt       2050 mAh Battery with Fast Charging
#
#                                                display  \
# 663  6.6 inches, 720 x 1612 px, 90 Hz Display with ...
# 101  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 292  6.6 inches, 1080 x 2400 px, 90 Hz Display with...
# 695  6.91 inches, 1080 x 2460 px Display with Punch...
# 245  6.6 inches, 1080 x 2400 px, 90 Hz Display with...
# 771  6.51 inches, 720 x 1600 px Display with Water ...
# 798  6.7 inches, 1440 x 3200 px, 120 Hz Display wit...
# 199  6.5 inches, 720 x 1600 px Display with Water D...
# 325  6.6 inches, 720 x 1600 px, 90 Hz Display with ...
# 174  4.7 inches, 750 x 1334 px Display with Large N...
#
#                                                 camera  \
# 663  50 MP + Depth Sensor Dual Rear & 8 MP Front Ca...
# 101              108 MP Quad Rear & 32 MP Front Camera
# 292        50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 695              108 MP Quad Rear & 16 MP Front Camera
# 245        50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 771         13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 798               64 MP Quad Rear & 10 MP Front Camera
# 199         13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 325                13 MP Dual Rear & 8 MP Front Camera
# 174                     12 MP Rear & 7 MP Front Camera
#
#                                    card           os
# 663  Memory Card Supported, upto 256 GB  Android v12
# 101  Memory Card Supported, upto 512 GB  Android v11
# 292     Memory Card (Hybrid), upto 1 TB  Android v11
# 695  Memory Card Supported, upto 256 GB  Android v12
# 245     Memory Card (Hybrid), upto 1 TB  Android v11
# 771    Memory Card Supported, upto 1 TB  Android v12
# 798     Memory Card (Hybrid), upto 1 TB  Android v10
# 199    Memory Card Supported, upto 1 TB  Android v12
# 325  Memory Card Supported, upto 256 GB  Android v12
# 174           Memory Card Not Supported    iOS v13.0

# %%
clean_phone_data(final_df)
# Out:
#         price  rating     brand         model_name  number_of_sim  has_5G  \
# 0     54999.0    89.0   Oneplus              11 5G              2    True
# 1     19989.0    81.0   Oneplus  Nord CE 2 Lite 5G              2    True
# 2     16499.0    75.0   Samsung      Galaxy A14 5G              2    True
# 3     14999.0    81.0  Motorola        Moto G62 5G              2    True
# 4     24999.0    82.0    Realme        10 Pro Plus              2    True
# ...       ...     ...       ...                ...            ...     ...
# 1010   8720.0    64.0    Realme    Narzo 50i Prime              2   False
# 1016  14990.0    75.0     Honor              X8 5G              2    True
# 1017  28990.0    85.0      Poco           X4 GT 5G              2    True
# 1018  19990.0    80.0  Motorola        Moto G91 5G              2    True
# 1019  24990.0    74.0   Samsung     Galaxy M52s 5G              2    True
#
#       has_NFC  has_IR_Blaster  cpu_speed  number_of_cores  ... fast_charging  \
# 0        True           False       3.20                8  ...          True
# 1       False           False       2.20                8  ...          True
# 2       False           False       2.40                8  ...          True
# 3       False           False       2.20                8  ...          True
# 4       False           False       2.60                8  ...          True
# ...       ...             ...        ...              ...  ...           ...
# 1010    False           False       1.82                8  ...          True
# 1016    False           False       2.20                8  ...          True
# 1017     True            True       2.85                8  ...          True
# 1018     True           False       2.20                8  ...          True
# 1019    False           False        NaN                8  ...          True
#
#       fast_charging_power  display_size   resolution  refresh_rate  \
# 0                     100          6.70  1440 x 3216           120
# 1                      33          6.59  1080 x 2412           120
# 2                      15          6.60  1080 x 2408            90
# 3                     NaN          6.55  1080 x 2400           120
# 4                      67          6.70  1080 x 2412           120
# ...                   ...           ...          ...           ...
# 1010                   10          6.50   720 x 1600           NaN
# 1016                    5          6.50   720 x 1600           NaN
# 1017                   67          6.60  1080 x 2460           144
# 1018                  NaN          6.80  1080 x 2400           NaN
# 1019                  NaN          6.50  1080 x 2400           NaN
#
#      rear_camera  front_camera num_of_cameras card_size  has_card
# 0           50.0          16.0         Triple       NaN     False
# 1           64.0          16.0         Triple    1024.0      True
# 2           50.0          13.0         Triple    1024.0      True
# 3           50.0          16.0         Triple    1024.0      True
# 4          108.0          16.0         Triple       NaN     False
# ...          ...           ...            ...       ...       ...
# 1010         8.0           5.0            NaN    1024.0      True
# 1016        48.0           8.0         Triple    1024.0      True
# 1017        64.0          16.0         Triple       NaN     False
# 1018       108.0          32.0         Triple    1024.0      True
# 1019        64.0          32.0         Triple    1024.0      True
#
# [725 rows x 24 columns]

# %% [markdown]
# ## Left shifted phones

# %%
get_left_shifted_phones(df).shape
# Out:
# (285, 11)

# %%
(
    get_left_shifted_phones(df)
    .drop(index=[111, 149, 307, 363, 439, 448, 607, 628, 656, 754, 762, 853, 913, 914])
    .sample(50)
#     .loc[:,"card"]
#     .unique()
)
# Out:
#                                                model      price  rating  \
# 881                                 Nokia 110 (2022)     ₹1,599     NaN
# 493                           Nubia Red Magic 7S Pro    ₹60,990    86.0
# 740                          OPPO Reno 6 Pro Plus 5G    ₹44,990    87.0
# 168                                     iQOO 9 SE 5G    ₹30,990    83.0
# 649                            Huawei Mate 40 Pro 4G    ₹69,990     NaN
# 425             OnePlus 10 Pro 5G (12GB RAM + 512GB)    ₹74,999     NaN
# 267                                    OnePlus Ace 2    ₹34,999    84.0
# 229                               OPPO Reno 8 Pro 5G    ₹45,999    86.0
# 858                                      Oppo Reno 5    ₹29,990    83.0
# 380                               Samsung Galaxy S21    ₹48,900    88.0
# 640                                   Nokia 105 Plus     ₹1,299     NaN
# 724                            Huawei Mate 50 Pro 5G    ₹99,990    85.0
# 962                            Nubia Red Magic 6S 5G    ₹44,999    84.0
# 676               Xiaomi Mi 11X 5G (8GB RAM + 128GB)    ₹25,990    83.0
# 1000                                 XTouch F40 Flip     ₹1,999     NaN
# 516                                   OnePlus 12 Pro    ₹69,999     NaN
# 812               Realme GT Neo 3T (8GB RAM + 256GB)    ₹28,499    82.0
# 573                                 Nokia 105 (2019)     ₹1,299     NaN
# 894                              Royole FlexPai 3 5G  ₹1,49,999    87.0
# 851                                       Realme Q2i     ₹9,999    69.0
# 722                        Motorola Moto Edge 30 Neo    ₹31,990    84.0
# 540                             ZTE Axon 40 Ultra 5G    ₹61,990    89.0
# 700                                 Nubia Z40 Pro 5G    ₹49,990    84.0
# 401                                  Realme GT Neo 5    ₹34,999    83.0
# 665                                     itel it2163S       ₹958     NaN
# 107                            Samsung Galaxy S22 5G    ₹49,999    86.0
# 971                                    iQOO 7 Legend    ₹39,990    84.0
# 836                                     Vivo Y55s 5G    ₹19,990    79.0
# 896                              Tecno Phantom X Pro    ₹22,999    84.0
# 272                               Google Pixel 6 Pro    ₹54,300    89.0
# 342                            Tecno Camon 19 Pro 5G    ₹21,999    82.0
# 424                                      Honor 70 5G    ₹39,990    88.0
# 110                                 Tecno Phantom X2    ₹39,999    85.0
# 532                    Samsung Guru Music 2 Dual Sim     ₹1,949     NaN
# 423                                 Xiaomi 12S Ultra    ₹69,990     NaN
# 463                                 OPPO Reno 10 Pro    ₹42,990    86.0
# 500                                   Honor 60 SE 5G    ₹24,990    75.0
# 699                            Samsung Guru GT-E1215     ₹1,850     NaN
# 945                       Motorola Moto Edge X30 Pro    ₹59,990     NaN
# 196          OPPO Reno 8 Pro House of Dragon Edition    ₹45,999    86.0
# 772                                         Honor X8    ₹16,999    76.0
# 93                              Vivo X90 Pro Plus 5G    ₹73,999     NaN
# 583                          Motorola Edge 40 Pro 5G    ₹59,990    89.0
# 29                                    OnePlus 11 Pro    ₹69,999     NaN
# 895                                   Tecno Camon 18    ₹11,499    75.0
# 641    Samsung Galaxy S22 Ultra 5G (8GB RAM + 128GB)    ₹99,990     NaN
# 159                                  Oppo Find N2 5G    ₹94,990     NaN
# 269                                  Nothing Phone 2    ₹39,990    88.0
# 908   Samsung Galaxy S21 Ultra 5G (12GB RAM + 128GB)  ₹1,01,999     NaN
# 551                                  itel Magic 2 4G     ₹2,399     NaN
#
#                                                     sim  \
# 881                                            Dual Sim
# 493             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 740             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 168             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 649     Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 425             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 267             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 229             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 858                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 380             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 640                                            Dual Sim
# 724             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 962             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 676      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 1000                                           Dual Sim
# 516       Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 812                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 573                                          Single Sim
# 894                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 851                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 722             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 540             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 700             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 401             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 665                                            Dual Sim
# 107             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 971             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 836                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 896                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 272             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 342             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 424             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 110             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 532                                            Dual Sim
# 423   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 463             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 500                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 699                                          Single Sim
# 945             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 196             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 772                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 93    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 583             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 29              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 895                 Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 641             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 159             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 269             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 908             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 551                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
#
#                                               processor  \
# 881                                             No Wifi
# 493   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 740        Snapdragon 870, Octa Core, 3.2 GHz Processor
# 168     Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 649          Kirin  9000, Octa Core, 3.13 GHz Processor
# 425      Snapdragon  8 Gen1, Octa Core, 3 GHz Processor
# 267    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 229   Dimensity 8100-Max, Octa Core, 2.85 GHz Processor
# 858     Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 380          Exynos  2100, Octa Core, 2.9 GHz Processor
# 640                              4 MB RAM, 4 MB inbuilt
# 724          Kirin 9000E, Octa Core, 3.13 GHz Processor
# 962       Snapdragon 888+, Octa Core, 2.9 GHz Processor
# 676        Snapdragon 870, Octa Core, 3.2 GHz Processor
# 1000                                              No 3G
# 516    Snapdragon  8 Gen2, Octa Core, 3.2 GHz Processor
# 812        Snapdragon 870, Octa Core, 3.2 GHz Processor
# 573                                             No Wifi
# 894       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 851           Dimensity 720, Octa Core, 2 GHz Processor
# 722        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 540       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 700      Snapdragon  8 Gen1, Octa Core, 3 GHz Processor
# 401   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 665                              4 MB RAM, 4 MB inbuilt
# 107      Snapdragon  8 Gen1, Octa Core, 3 GHz Processor
# 971     Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 836      Dimensity 700 5G, Octa Core, 2.2 GHz Processor
# 896            Helio G95, Octa Core, 2.05 GHz Processor
# 272        Google  Tensor, Octa Core, 2.8 GHz Processor
# 342      Dimensity 810 5G, Octa Core, 2.4 GHz Processor
# 424   Snapdragon  778G Plus, Octa Core, 2.5 GHz Proc...
# 110       Dimensity 9000, Octa Core, 3.05 GHz Processor
# 532                                             No Wifi
# 423    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 463       Dimensity 9000, Octa Core, 3.05 GHz Processor
# 500           Dimensity 900, Octa Core, 2 GHz Processor
# 699                                     800 mAh Battery
# 945    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 196   Dimensity 8100-Max, Octa Core, 2.85 GHz Processor
# 772       Snapdragon  680, Octa Core, 2.4 GHz Processor
# 93      Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 583     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 29     Snapdragon  8 Gen2, Octa Core, 3.2 GHz Processor
# 895              Helio  G88, Octa Core, 2 GHz Processor
# 641      Snapdragon  8 Gen1, Octa Core, 3 GHz Processor
# 159    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 269    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 908          Exynos  2100, Octa Core, 2.9 GHz Processor
# 551                                               No 3G
#
#                                    ram  \
# 881             4 MB RAM, 4 MB inbuilt
# 493          12 GB RAM, 256 GB inbuilt
# 740           8 GB RAM, 128 GB inbuilt
# 168           8 GB RAM, 128 GB inbuilt
# 649           8 GB RAM, 128 GB inbuilt
# 425          12 GB RAM, 512 GB inbuilt
# 267           8 GB RAM, 128 GB inbuilt
# 229          12 GB RAM, 256 GB inbuilt
# 858           8 GB RAM, 128 GB inbuilt
# 380           8 GB RAM, 128 GB inbuilt
# 640                    800 mAh Battery
# 724           8 GB RAM, 256 GB inbuilt
# 962           8 GB RAM, 128 GB inbuilt
# 676           8 GB RAM, 128 GB inbuilt
# 1000                           No Wifi
# 516          12 GB RAM, 256 GB inbuilt
# 812           8 GB RAM, 256 GB inbuilt
# 573             4 MB RAM, 4 MB inbuilt
# 894           8 GB RAM, 128 GB inbuilt
# 851           4 GB RAM, 128 GB inbuilt
# 722           8 GB RAM, 128 GB inbuilt
# 540           8 GB RAM, 128 GB inbuilt
# 700           8 GB RAM, 128 GB inbuilt
# 401           8 GB RAM, 128 GB inbuilt
# 665                   1200 mAh Battery
# 107           8 GB RAM, 128 GB inbuilt
# 971           8 GB RAM, 128 GB inbuilt
# 836           8 GB RAM, 128 GB inbuilt
# 896           8 GB RAM, 256 GB inbuilt
# 272          12 GB RAM, 128 GB inbuilt
# 342           8 GB RAM, 128 GB inbuilt
# 424          12 GB RAM, 512 GB inbuilt
# 110           8 GB RAM, 256 GB inbuilt
# 532     Single Core, 208 MHz Processor
# 423           8 GB RAM, 256 GB inbuilt
# 463          16 GB RAM, 256 GB inbuilt
# 500           8 GB RAM, 128 GB inbuilt
# 699   1.5 inches, 120 x 120 px Display
# 945           8 GB RAM, 128 GB inbuilt
# 196          12 GB RAM, 256 GB inbuilt
# 772           6 GB RAM, 128 GB inbuilt
# 93           12 GB RAM, 256 GB inbuilt
# 583           8 GB RAM, 128 GB inbuilt
# 29            8 GB RAM, 128 GB inbuilt
# 895           4 GB RAM, 128 GB inbuilt
# 641           8 GB RAM, 128 GB inbuilt
# 159          12 GB RAM, 256 GB inbuilt
# 269           8 GB RAM, 128 GB inbuilt
# 908          12 GB RAM, 128 GB inbuilt
# 551                               T117
#
#                                         battery  \
# 881                            1000 mAh Battery
# 493    5000 mAh Battery with 135W Fast Charging
# 740     4500 mAh Battery with 65W Fast Charging
# 168     4500 mAh Battery with 66W Fast Charging
# 649     4400 mAh Battery with 66W Fast Charging
# 425     5000 mAh Battery with 80W Fast Charging
# 267    5000 mAh Battery with 100W Fast Charging
# 229     4500 mAh Battery with 80W Fast Charging
# 858     4300 mAh Battery with 65W Fast Charging
# 380     4000 mAh Battery with 25W Fast Charging
# 640           1.77 inches, 128 x 160 px Display
# 724     4500 mAh Battery with 66W Fast Charging
# 962     5050 mAh Battery with 30W Fast Charging
# 676     4520 mAh Battery with 33W Fast Charging
# 1000                   32 MB RAM, 32 MB inbuilt
# 516    4800 mAh Battery with 150W Fast Charging
# 812     5000 mAh Battery with 80W Fast Charging
# 573                             800 mAh Battery
# 894                            3360 mAh Battery
# 851     5000 mAh Battery with 18W Fast Charging
# 722     4020 mAh Battery with 68W Fast Charging
# 540     5000 mAh Battery with 65W Fast Charging
# 700     5000 mAh Battery with 80W Fast Charging
# 401    4600 mAh Battery with 240W Fast Charging
# 665            1.8 inches, 160 x 128 px Display
# 107     3700 mAh Battery with 25W Fast Charging
# 971     4000 mAh Battery with 66W Fast Charging
# 836     6000 mAh Battery with 18W Fast Charging
# 896     5000 mAh Battery with 44W Fast Charging
# 272     5003 mAh Battery with 30W Fast Charging
# 342     5000 mAh Battery with 33W Fast Charging
# 424     4800 mAh Battery with 66W Fast Charging
# 110     5160 mAh Battery with 45W Fast Charging
# 532                             800 mAh Battery
# 423     4860 mAh Battery with 67W Fast Charging
# 463    5000 mAh Battery with 120W Fast Charging
# 500     4300 mAh Battery with 66W Fast Charging
# 699                              No Rear Camera
# 945    4450 mAh Battery with 125W Fast Charging
# 196     4500 mAh Battery with 80W Fast Charging
# 772   4000 mAh Battery with 22.5W Fast Charging
# 93      4700 mAh Battery with 80W Fast Charging
# 583    4800 mAh Battery with 125W Fast Charging
# 29     4500 mAh Battery with 100W Fast Charging
# 895     5000 mAh Battery with 18W Fast Charging
# 641     5000 mAh Battery with 45W Fast Charging
# 159     4520 mAh Battery with 67W Fast Charging
# 269     4700 mAh Battery with 66W Fast Charging
# 908     5000 mAh Battery with 25W Fast Charging
# 551                   64 MB RAM, 128 MB inbuilt
#
#                                                 display  \
# 881                   1.77 inches, 120 x 160 px Display
# 493          6.8 inches, 1080 x 2400 px, 120 Hz Display
# 740   6.55 inches, 1080 x 2400 px, 90 Hz Display wit...
# 168   6.62 inches, 1080 x 2400 px, 120 Hz Display wi...
# 649   6.76 inches, 1344 x 2772 px, 90 Hz Display wit...
# 425   6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 267   6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 229   6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 858   6.43 inches, 1080 x 2400 px Display with Punch...
# 380   6.2 inches, 1080 x 2400 px, 120 Hz Display wit...
# 640                                      No Rear Camera
# 724   6.76 inches, 1440 x 3200 px, 120 Hz Display wi...
# 962          6.8 inches, 1080 x 2400 px, 165 Hz Display
# 676   6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 1000                                    800 mAh Battery
# 516   6.73 inches, 1440 x 3412 px, 144 Hz Display wi...
# 812   6.62 inches, 1080 x 2400 px, 120 Hz Display wi...
# 573                   1.77 inches, 120 x 160 px Display
# 894                  7.2 inches, 1440 x 1920 px Display
# 851   6.5 inches, 720 x 1600 px Display with Water D...
# 722   6.28 inches, 1080 x 2400 px, 120 Hz Display wi...
# 540          6.8 inches, 1116 x 2480 px, 120 Hz Display
# 700   6.67 inches, 1080 x 2400 px, 144 Hz Display wi...
# 401   6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 665                                      No Rear Camera
# 107   6.1 inches, 1080 x 2340 px, 120 Hz Display wit...
# 971   6.62 inches, 1080 x 2400 px, 120 Hz Display wi...
# 836   6.58 inches, 1080 x 2408 px Display with Water...
# 896   6.7 inches, 1080 x 2400 px, 120 Hz Display wit...
# 272   6.71 inches, 1440 x 3120 px, 120 Hz Display wi...
# 342   6.8 inches, 1080 x 2460 px, 120 Hz Display wit...
# 424   6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 110   6.8 inches, 1080 x 2400 px, 120 Hz Display wit...
# 532                      2 inches, 128 x 160 px Display
# 423   6.73 inches, 1440 x 3200 px, 120 Hz Display wi...
# 463   6.73 inches, 1080 x 2412 px, 120 Hz Display wi...
# 500   6.67 inches, 1080 x 2340 px, 120 Hz Display wi...
# 699                                         No FM Radio
# 945   6.67 inches, 1080 x 2340 px, 144 Hz Display wi...
# 196   6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 772   6.7 inches, 1080 x 2388 px, 90 Hz Display with...
# 93    6.78 inches, 1440 x 3200 px, 120 Hz Display wi...
# 583   6.7 inches, 1080 x 2460 px, 165 Hz Display wit...
# 29    6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 895   6.8 inches, 1080 x 2460 px, 90 Hz Display with...
# 641   6.8 inches, 1440 x 3080 px, 120 Hz Display wit...
# 159   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 269   6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 908   6.8 inches, 1440 x 3200 px, 120 Hz Display wit...
# 551                                    1900 mAh Battery
#
#                                                  camera  \
# 881                   Memory Card Supported, upto 32 GB
# 493   64 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 740                50 MP Quad Rear & 32 MP Front Camera
# 168   48 MP + 13 MP + 2 MP Triple Rear & 16 MP Front...
# 649   50 MP + 20 MP + 12 MP Triple Rear & 13 MP Dual...
# 425   50 MP + 48 MP + 8 MP Triple Rear & 32 MP Front...
# 267   50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 229   50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 858                64 MP Quad Rear & 32 MP Front Camera
# 380   64 MP + 12 MP + 12 MP Triple Rear & 10 MP Fron...
# 640                   Memory Card Supported, upto 32 GB
# 724   64 MP + 50 MP + 13 MP Triple Rear & 13 MP Fron...
# 962   64 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 676   48 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...
# 1000                  1.77 inches, 240 x 320 px Display
# 516   108 MP + 50 MP + 48 MP Triple Rear & 32 MP Fro...
# 812   64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 573                                      No Rear Camera
# 894                      Foldable Display, Dual Display
# 851   13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 722        64 MP + 13 MP Dual Rear & 32 MP Front Camera
# 540   64 MP + 64 MP + 64 MP Triple Rear & 16 MP Fron...
# 700   64 MP + 50 MP + 8 MP Triple Rear & 16 MP Front...
# 401   50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 665                   Memory Card Supported, upto 32 GB
# 107   50 MP + 12 MP + 10 MP Triple Rear & 10 MP Fron...
# 971   48 MP + 13 MP + 13 MP Triple Rear & 16 MP Fron...
# 836          50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 896    50 MP Quad Rear & 48 MP + 8 MP Dual Front Camera
# 272   50 MP + 48 MP + 12 MP Triple Rear & 11.1 MP Fr...
# 342   64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 424   54 MP + 50 MP + 2 MP Triple Rear & 32 MP Front...
# 110   64 MP + 13 MP + 2 MP Triple Rear & 32 MP Front...
# 532                                      No Rear Camera
# 423   50 MP + 48 MP + 48 MP Triple Rear & 32 MP Fron...
# 463         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 500   64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 699                                                 NaN
# 945   200 MP + 50 MP + 12 MP Triple Rear & 60 MP Fro...
# 196   50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 772                64 MP Quad Rear & 16 MP Front Camera
# 93               50.3 MP Quad Rear & 32 MP Front Camera
# 583   50 MP + 50 MP + 12 MP Triple Rear & 60 MP Fron...
# 29    50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 895   48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 641               108 MP Quad Rear & 40 MP Front Camera
# 159                      Foldable Display, Dual Display
# 269   50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 908               108 MP Quad Rear & 40 MP Front Camera
# 551                    2.4 inches, 240 x 320 px Display
#
#                                                    card  \
# 881                                                 NaN
# 493                                         Android v12
# 740                                         Android v11
# 168                                         Android v12
# 649                   Memory Card (Hybrid), upto 256 GB
# 425                                       Android v12.1
# 267                                         Android v13
# 229                                         Android v12
# 858                                         Android v11
# 380                                         Android v10
# 640                                           Bluetooth
# 724                           Memory Card Not Supported
# 962                                         Android v11
# 676                                         Android v11
# 1000                                       Dual Display
# 516                                         Android v13
# 812                                         Android v12
# 573                                                 NaN
# 894   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 851                                         Android v10
# 722                                         Android v12
# 540                                         Android v12
# 700                                         Android v12
# 401                                         Android v13
# 665                                           Bluetooth
# 107                                         Android v12
# 971                                         Android v11
# 836                                         Android v11
# 896                                         Android v11
# 272                                         Android v12
# 342                                         Android v12
# 424                                         Android v12
# 110                                         Android v12
# 532                   Memory Card Supported, upto 16 GB
# 423                                         Android v12
# 463                                         Android v13
# 500                                         Android v11
# 699                                                 NaN
# 945                                         Android v12
# 196                                         Android v12
# 772                                         Android v11
# 93                                          Android v13
# 583                                         Android v12
# 29                                          Android v13
# 895                                         Android v11
# 641                                         Android v12
# 159   50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 269                                         Android v13
# 908                                         Android v10
# 551                                  1.3 MP Rear Camera
#
#                                       os
# 881                                  NaN
# 493                          No FM Radio
# 740                          No FM Radio
# 168                          No FM Radio
# 649                         Harmony v2.0
# 425                          No FM Radio
# 267                          No FM Radio
# 229                          No FM Radio
# 858                            Bluetooth
# 380                          No FM Radio
# 640                                  NaN
# 724                     Hongmeng OS v4.0
# 962                          No FM Radio
# 676                          No FM Radio
# 1000                  1.3 MP Rear Camera
# 516                          No FM Radio
# 812                          No FM Radio
# 573                                  NaN
# 894   Memory Card Supported, upto 256 GB
# 851                          No FM Radio
# 722                          No FM Radio
# 540                          No FM Radio
# 700                          No FM Radio
# 401                          No FM Radio
# 665                                  NaN
# 107                            Bluetooth
# 971                          No FM Radio
# 836                            Bluetooth
# 896                            Bluetooth
# 272                          No FM Radio
# 342                            Bluetooth
# 424                          No FM Radio
# 110                          No FM Radio
# 532                                  NaN
# 423                          No FM Radio
# 463                          No FM Radio
# 500                          No FM Radio
# 699                                  NaN
# 945                          No FM Radio
# 196                          No FM Radio
# 772                          No FM Radio
# 93                           No FM Radio
# 583                          No FM Radio
# 29                           No FM Radio
# 895                            Bluetooth
# 641                            Bluetooth
# 159            Memory Card Not Supported
# 269                          No FM Radio
# 908                          No FM Radio
# 551    Memory Card Supported, upto 64 GB

# %%
(
    get_left_shifted_phones(df)
    .drop(index=[111, 149, 307, 363, 439, 448, 607, 628, 656, 754, 762, 853, 913, 914])
    # .loc[:,"card"]
    # .unique()
)
# Out:
#                             model    price  rating  \
# 8                 Nothing Phone 1  ₹26,749    85.0
# 9              OnePlus Nord 2T 5G  ₹28,999    84.0
# 12    Xiaomi Redmi Note 12 Pro 5G  ₹24,762    79.0
# 17           OPPO Reno 9 Pro Plus  ₹45,999    86.0
# 18                 OnePlus 10R 5G  ₹32,999    86.0
# ...                           ...      ...     ...
# 1009                Xiaomi Civi 3  ₹32,990    86.0
# 1011                 Oppo Find X6  ₹69,990    89.0
# 1012                    itel A23s   ₹4,787     NaN
# 1013           Google Pixel 8 Pro  ₹70,990    80.0
# 1015   Motorola Moto Edge S30 Pro  ₹34,990    83.0
#
#                                                     sim  \
# 8               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 9               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 12       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 17              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 18              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...                                                 ...
# 1009  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1011            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1012                            Dual Sim, 3G, 4G, Wi-Fi
# 1013            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                               processor  \
# 8     Snapdragon 778G Plus, Octa Core, 2.5 GHz Proce...
# 9           Dimensity  1300, Octa Core, 3 GHz Processor
# 12         Dimensity 1080, Octa Core, 2.6 GHz Processor
# 17     Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 18    Dimensity 8100 Max, Octa Core, 2.85 GHz Processor
# ...                                                 ...
# 1009       Dimensity 8200, Octa Core, 3.1 GHz Processor
# 1011    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1012  Spreadtrum  SC9832E, Quad Core, 1.4 GHz Processor
# 1013              Google  Tensor 3, Octa Core Processor
# 1015      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
#
#                             ram                                    battery  \
# 8      8 GB RAM, 128 GB inbuilt    4500 mAh Battery with 33W Fast Charging
# 9      8 GB RAM, 128 GB inbuilt    4500 mAh Battery with 80W Fast Charging
# 12     6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# 17    16 GB RAM, 256 GB inbuilt    4700 mAh Battery with 80W Fast Charging
# 18     8 GB RAM, 128 GB inbuilt    5000 mAh Battery with 80W Fast Charging
# ...                         ...                                        ...
# 1009   8 GB RAM, 256 GB inbuilt    5000 mAh Battery with 80W Fast Charging
# 1011   8 GB RAM, 256 GB inbuilt   4700 mAh Battery with 120W Fast Charging
# 1012    2 GB RAM, 32 GB inbuilt                           3020 mAh Battery
# 1013  12 GB RAM, 256 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
#
#                                                 display  \
# 8     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 9     6.43 inches, 1080 x 2400 px, 90 Hz Display wit...
# 12    6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 17    6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 18    6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1009  6.7 inches, 1080 x 2400 px, 120 Hz Display wit...
# 1011  6.73 inches, 1080 x 2400 px, 120 Hz Display wi...
# 1012                     5 inches, 854 x 480 px Display
# 1013  6.73 inches, 1440 x 3120 px, 120 Hz Display wi...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
#
#                                                  camera         card  \
# 8          50 MP + 50 MP Dual Rear & 16 MP Front Camera  Android v12
# 9     50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...  Android v12
# 12    50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...  Android v12
# 17    50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...  Android v13
# 18    50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...  Android v12
# ...                                                 ...          ...
# 1009  64 MP + 20 MP + 2 MP Triple Rear & 32 MP + 32 ...  Android v13
# 1011  50 MP + 48 MP + 32 MP Triple Rear & 32 MP Fron...  Android v12
# 1012                                   2 MP Rear Camera  Android v11
# 1013  50 MP + 50 MP + 50 MP Triple Rear & 12 MP Fron...  Android v13
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...  Android v12
#
#                os
# 8     No FM Radio
# 9     No FM Radio
# 12    No FM Radio
# 17    No FM Radio
# 18      Bluetooth
# ...           ...
# 1009  No FM Radio
# 1011  No FM Radio
# 1012  No FM Radio
# 1013  No FM Radio
# 1015  No FM Radio
#
# [271 rows x 11 columns]

# %%
index_of_left_shifted_phones = (
                                get_left_shifted_phones(df_without_feature_phones)
                                .drop(index=[111, 149, 307, 363, 439, 448, 607, 628, 762, 853, 913, 914])
                                .loc[:,"card"]
                                .str.contains(pat="Android|iOS",case=False)
                                .index.to_list()
                            )

# %% [markdown]
# ### **Apple data** --> left shifted phones

# %%
apple_no_shifting = get_left_shifted_phones(get_apple_phones(df)).loc[:, :"ram"]

# %%
apple_shifting = get_left_shifted_phones(get_apple_phones(df)).loc[:, "battery":].shift(periods=1, axis=1)

# %%
apple_correct_data = apple_no_shifting.join(apple_shifting)

apple_correct_data
# Out:
#                             model      price  rating  \
# 111               Apple iPhone 12    ₹51,999    74.0
# 149          Apple iPhone 12 Mini    ₹40,999    74.0
# 307       Apple iPhone 12 (128GB)    ₹55,999    75.0
# 363  Apple iPhone 12 Mini (128GB)    ₹45,999    75.0
# 439        Apple iPhone SE 3 2022    ₹43,900     NaN
# 448           Apple iPhone 15 Pro  ₹1,30,990    75.0
# 607               Apple iPhone 7s    ₹52,990     NaN
# 628   Apple iPhone 12 Pro (512GB)  ₹1,39,900    80.0
# 656          Apple iPhone SE 2020    ₹39,900    63.0
# 754    Apple iPod Touch (7th Gen)    ₹18,900     NaN
# 762             Apple iPhone SE 4    ₹49,990    60.0
# 853   Apple iPhone 12 Pro (256GB)  ₹1,19,900    80.0
# 913  Apple iPhone 12 Mini (256GB)    ₹55,999    75.0
# 914       Apple iPhone 12 (256GB)    ₹67,999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 607         Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 656      Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 754                                    Wi-Fi
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 853  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                          processor  \
# 111       Bionic A14, Hexa Core, 3.1 GHz Processor
# 149       Bionic A14, Hexa Core, 3.1 GHz Processor
# 307       Bionic A14, Hexa Core, 3.1 GHz Processor
# 363       Bionic A14, Hexa Core, 3.1 GHz Processor
# 439     Bionic  A15, Hexa Core, 3.22 GHz Processor
# 448                                    Bionic  A16
# 607  Fusion APL1024, Quad Core, 2.37 GHz Processor
# 628       Bionic A14, Hexa Core, 3.1 GHz Processor
# 656      A13 Bionic, Hexa Core, 2.65 GHz Processor
# 754                                  32 GB inbuilt
# 762     Bionic  A15, Hexa Core, 3.22 GHz Processor
# 853       Bionic A14, Hexa Core, 3.1 GHz Processor
# 913       Bionic A14, Hexa Core, 3.1 GHz Processor
# 914       Bionic A14, Hexa Core, 3.1 GHz Processor
#
#                                  ram battery  \
# 111          4 GB RAM, 64 GB inbuilt    None
# 149          4 GB RAM, 64 GB inbuilt    None
# 307         4 GB RAM, 128 GB inbuilt    None
# 363         4 GB RAM, 128 GB inbuilt    None
# 439                    64 GB inbuilt    None
# 448         8 GB RAM, 128 GB inbuilt    None
# 607          3 GB RAM, 32 GB inbuilt    None
# 628         6 GB RAM, 512 GB inbuilt    None
# 656          3 GB RAM, 64 GB inbuilt    None
# 754  4 inches, 640 x 1136 px Display    None
# 762                    64 GB inbuilt    None
# 853         6 GB RAM, 256 GB inbuilt    None
# 913         4 GB RAM, 256 GB inbuilt    None
# 914         4 GB RAM, 256 GB inbuilt    None
#
#                                                display  \
# 111  6.1 inches, 1170 x 2532 px Display with Large ...
# 149                 5.4 inches, 1080 x 2340 px Display
# 307  6.1 inches, 1170 x 2532 px Display with Large ...
# 363                 5.4 inches, 1080 x 2340 px Display
# 439                  4.7 inches, 750 x 1334 px Display
# 448  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 607                                   2230 mAh Battery
# 628  6.1 inches, 1170 x 2532 px Display with Large ...
# 656            1821 mAh Battery with 18W Fast Charging
# 754                    8 MP Rear & 1.2 MP Front Camera
# 762                  6.1 inches, 750 x 1580 px Display
# 853  6.1 inches, 1170 x 2532 px Display with Large ...
# 913                 5.4 inches, 1080 x 2340 px Display
# 914  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                 camera  \
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 307       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 363       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 439                     12 MP Rear & 7 MP Front Camera
# 448  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 607                  4.7 inches, 750 x 1334 px Display
# 628  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 656                  4.7 inches, 750 x 1334 px Display
# 754                                            iOS v12
# 762                  12 MP Rear & 10.8 MP Front Camera
# 853  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 913       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914       12 MP + 12 MP Dual Rear & 12 MP Front Camera
#
#                                card         os
# 111       Memory Card Not Supported    iOS v14
# 149       Memory Card Not Supported    iOS v14
# 307       Memory Card Not Supported    iOS v14
# 363       Memory Card Not Supported    iOS v14
# 439       Memory Card Not Supported    iOS v15
# 448       Memory Card Not Supported    iOS v15
# 607  13 MP Rear & 7 MP Front Camera    iOS v10
# 628       Memory Card Not Supported  iOS v14.0
# 656  12 MP Rear & 7 MP Front Camera    iOS v13
# 754                     No FM Radio  Bluetooth
# 762       Memory Card Not Supported    iOS v16
# 853       Memory Card Not Supported  iOS v14.0
# 913       Memory Card Not Supported    iOS v14
# 914       Memory Card Not Supported    iOS v14

# %%
apple_correct_data.isna().sum()
# Out:
# model         0
# price         0
# rating        3
# sim           0
# processor     0
# ram           0
# battery      14
# display       0
# camera        0
# card          0
# os            0
# dtype: int64

# %% [markdown]
# # Final Cleaning Step

# %%
725 + 14
# Out:
# 739

# %%
df_shifted_phones = df_without_feature_phones.loc[index_of_left_shifted_phones,:]

# %%
final_data = pd.concat([final_df, apple_correct_data, df_shifted_phones])

final_data.duplicated().sum()

# drop duplicates

final_data.drop_duplicates(inplace=True)

final_data.shape
# Out:
# (966, 11)

# %%
final_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
len(feature_phones_index)
# Out:
# 43

# %%
1020 - 43
# Out:
# 977

# %%
def clean_phone_data(data: pd.DataFrame):
    return(
        data
        .join(data["model"].pipe(clean_model))
        .join(data["sim"].pipe(clean_sim))
        .join(data["processor"].pipe(clean_processor))
        .join(data["ram"].pipe(clean_ram))
        .join(data["battery"].pipe(clean_battery))
        .join(data["display"].pipe(clean_display))
        .join(data["camera"].pipe(clean_camera))
        .join(data["card"].pipe(clean_card))
        .drop(columns=["model"] + data.columns[3:10].to_list() + ["os"])
        .assign(
            price=lambda df_ : df_["price"].pipe(clean_price)
        )
    )

# %%
cleaned_data = clean_phone_data(final_data)

cleaned_data.head()
# Out:
#      price  rating     brand         model_name  number_of_sim  has_5G  \
# 0  54999.0    89.0   Oneplus              11 5G              2    True
# 1  19989.0    81.0   Oneplus  Nord CE 2 Lite 5G              2    True
# 2  16499.0    75.0   Samsung      Galaxy A14 5G              2    True
# 3  14999.0    81.0  Motorola        Moto G62 5G              2    True
# 4  24999.0    82.0    Realme        10 Pro Plus              2    True
#
#    has_NFC  has_IR_Blaster  cpu_speed  number_of_cores  ... fast_charging  \
# 0     True           False        3.2                8  ...          True
# 1    False           False        2.2                8  ...          True
# 2    False           False        2.4                8  ...          True
# 3    False           False        2.2                8  ...          True
# 4    False           False        2.6                8  ...          True
#
#    fast_charging_power  display_size   resolution refresh_rate rear_camera  \
# 0                  100          6.70  1440 x 3216          120        50.0
# 1                   33          6.59  1080 x 2412          120        64.0
# 2                   15          6.60  1080 x 2408           90        50.0
# 3                  NaN          6.55  1080 x 2400          120        50.0
# 4                   67          6.70  1080 x 2412          120       108.0
#
#    front_camera num_of_cameras card_size  has_card
# 0          16.0         Triple       NaN     False
# 1          16.0         Triple    1024.0      True
# 2          13.0         Triple    1024.0      True
# 3          16.0         Triple    1024.0      True
# 4          16.0         Triple       NaN     False
#
# [5 rows x 24 columns]

# %%
# save as csv

cleaned_data.to_csv("cleaned_smartphones_data.csv", index=False)

# %%
# check for missing values in clean data

cleaned_data.isna().sum()
# Out:
# price                    0
# rating                  91
# brand                    0
# model_name               0
# number_of_sim            0
# has_5G                   0
# has_NFC                  0
# has_IR_Blaster           0
# cpu_speed               47
# number_of_cores          0
# processor_name          58
# memory                   8
# storage                  5
# capacity                18
# fast_charging           14
# fast_charging_power    210
# display_size             7
# resolution               7
# refresh_rate           365
# rear_camera             20
# front_camera            46
# num_of_cameras          77
# card_size              470
# has_card                 0
# dtype: int64

# %%
# shape of cleaned data

cleaned_data.shape
# Out:
# (966, 24)
